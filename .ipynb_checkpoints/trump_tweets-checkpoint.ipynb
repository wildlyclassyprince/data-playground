# %% [markdown]
# # Trump Tweets

# %%
# The usual suspects ...
import logging
import pandas as pd

# And their accomplices ...
from gensim import corpora
from gensim import models
from gensim import similarities
from nltk.corpus import stopwords
from nltk.tokenize import wordpunct_tokenize
from collections import defaultdict
from pprint import pprint

# Settings
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
tweets = pd.read_csv('realDonaldTrump_poll_tweets.csv')

# %%
tweets.shape
# Out:
# (448, 3)

# %%
tweets.head()
# Out:
#              id          created_at  \
# 0  7.656299e+17  8/16/2016 19:22:57
# 1  7.587319e+17  7/28/2016 18:32:31
# 2  7.583505e+17  7/27/2016 17:16:56
# 3  7.575775e+17  7/25/2016 14:05:27
# 4  7.536034e+17  7/14/2016 14:53:46
#
#                                                 text
# 0  It's just a 2-point race, Clinton 38%, Trump 3...
# 1  "@LallyRay: Poll: Donald Trump Sees 17-Point P...
# 2  Great new poll - thank you!\n#MakeAmericaGreat...
# 3  Great POLL numbers are coming out all over. Pe...
# 4  Another new poll. Thank you for your support! ...

# %%
# Text corpus
document = [i for i in tweets['text']]

# %%
# Removing common words and tokenize
stop_words = set(stopwords.words('english'))
stop_words.update(['.', ',', '"', "'", '?', '!', ':', ';', '(', ')', '[', ']', '{', '}'])
for doc in document:
    list_of_words = [i.lower() for i in wordpunct_tokenize(doc) if i.lower() not in stop_words]
stop_words.update(list_of_words)

# %%
# Removing common words
texts = [[word for word in doc.lower().split() if word not in stop_words] for doc in document]

# Removing words that appear only once
frequency = defaultdict(int)
for text in texts:
    for token in text:
        frequency[token] += 1

texts = [[token for token in text if frequency[token] > 1] for text in texts]

pprint(texts)
# Out:
# [['clinton', 'trump'],
#  ['poll:',
#   'donald',
#   'trump',
#   'two',
#   '-',
#   'breitbart',
#   '@realdonaldtrump"',
#   'great!'],
#  ['great', 'new', 'poll', '-', 'thank', 'you!', '#makeamericagreatagain'],
#  ['great',
#   'poll',
#   'numbers',
#   'coming',
#   'people',
#   'want',
#   'another',
#   'four',
#   'years',
#   'crooked',
#   'hillary',
#   'even'],
#  ['another', 'new', 'poll.', 'thank', 'support!', '#imwithyou'],
#  ['great', 'new', 'poll-', 'thank', 'america!', '#trump2016', '#imwithyou'],
#  ['despite', 'spending', 'day', 'ads', 'nationwide', 'zero'],
#  ['great', 'poll-', 'thank', 'you!'],
#  ['new', 'poll', '-', 'thank', 'you!', '#trump2016'],
#  ['new',
#   'q',
#   'poll',
#   'going',
#   'win',
#   'make',
#   'america',
#   'great',
#   'again!',
#   '#trump2016'],
#  ['poll',
#   'done',
#   '@abc',
#   '@washingtonpost',
#   'even',
#   'many',
#   'democrats',
#   'good.'],
#  ['hillary', 'clinton', 'change', 'old', 'spending', 'spending', 'polls!'],
#  ['@abc', 'poll', 'dishonest', '-', 'good!'],
#  ['many',
#   'great',
#   'things',
#   '-',
#   'new',
#   'poll',
#   'numbers',
#   'looking',
#   'good!',
#   'news',
#   'a.m.',
#   'today,',
#   'trump'],
#  ['poll', 'data', 'shows', 'far', 'best', 'keep', 'run'],
#  ['breaking',
#   'poll:',
#   'trump',
#   'gains',
#   '11',
#   'points',
#   'clinton',
#   'since',
#   'leads',
#   'crooked',
#   'hillary'],
#  ['great',
#   'new',
#   'poll-',
#   'thank',
#   'you!',
#   '#makeamericagreatagain',
#   '#trump2016'],
#  ['great', 'new', 'poll-', 'thank', 'you!'],
#  ['interesting', 'poll', 'results', 'far', 'go'],
#  ['john',
#   'kasich',
#   'hit',
#   'negative',
#   'drop',
#   'like',
#   'crooked',
#   'hillary',
#   'clinton.',
#   'win!'],
#  ['kasich', 'hillary', 'zero', 'negative', 'ads'],
#  ['@foxnews', '@realdonaldtrump', 'think', 'like', '#makeamericagreatagain!'],
#  ['new',
#   'cbs',
#   'poll',
#   'shows',
#   'supporters',
#   '&amp;',
#   'increased',
#   'support',
#   '@realdonaldtrump'],
#  ['wow,', 'great', 'new', 'poll-', 'new', 'thank', 'support!', '#trump2016'],
#  ['poll',
#   'shows',
#   '@realdonaldtrump',
#   'leads',
#   'among',
#   'registered',
#   'republican',
#   'thank',
#   'you!'],
#  ['come',
#   '@todayshow',
#   '&amp;',
#   '@chucktodd',
#   'new',
#   '@nbcnews',
#   'poll',
#   'hillary',
#   'poll'],
#  ['believe',
#   '@foxnews',
#   'polls,',
#   'another',
#   'phony',
#   'hit',
#   'job',
#   'me.',
#   'beat',
#   'hillary',
#   'clinton',
#   'easily',
#   'general',
#   'election.'],
#  ['trump', 'poll', 'numbers', 'race.'],
#  ['yet',
#   'another',
#   '-',
#   'four',
#   'people.',
#   'highest',
#   'reuters',
#   'poll',
#   'yet!',
#   'thank',
#   'you!'],
#  ["can't",
#   'watch',
#   'crazy',
#   'megyn',
#   '43%',
#   'never',
#   'four',
#   'people',
#   'race.',
#   'two',
#   'big',
#   '&amp;',
#   'over!'],
#  ['hear',
#   '@nbcnews',
#   '@wsj',
#   'came',
#   'another',
#   'one',
#   'phony',
#   'polls.',
#   'totally',
#   'last',
#   'poll'],
#  ['failed',
#   'presidential',
#   'candidate',
#   'graham',
#   'me.',
#   'run,',
#   '7%',
#   'got',
#   'out.'],
#  ['anyone',
#   'listen',
#   'failed',
#   'presidential',
#   'candidate',
#   'rand',
#   'paul',
#   '2nd'],
#  ['.@cnn',
#   'poll',
#   'hit',
#   '49%',
#   'trump.',
#   'interesting',
#   'numbers',
#   'gone',
#   'far',
#   'since',
#   'lightweight',
#   'marco',
#   'rubio',
#   'nasty.',
#   'love',
#   'it!'],
#  ['michigan',
#   'poll',
#   'trump',
#   'rubio',
#   'cruz',
#   'kasich',
#   'carson',
#   '@realdonaldtrump"',
#   'wow!'],
#  ['wow,',
#   'every',
#   'poll',
#   'said',
#   'debate',
#   'last',
#   'night.',
#   'great',
#   'honor!'],
#  ['@realdonaldtrump', '@cnn', 'almost'],
#  ['online', 'winning', 'debate.', 'really', 'good.'],
#  ['thank', 'you!', '#gopdebate', '#makeamericagreatagain'],
#  ['great', 'new', 'poll.', 'thank', '#votetrump', '#makeamericagreatagain'],
#  ['ted',
#   'cruz',
#   'showing',
#   'beat',
#   'hillary',
#   'clinton',
#   'head',
#   'head.',
#   'check',
#   'poll',
#   'q',
#   'poll.'],
#  ['picked',
#   'many',
#   'jeb',
#   'bush',
#   'got',
#   'others',
#   'drop',
#   'out,',
#   'pick',
#   'more.'],
#  ['poll', 'say', 'beat', 'hillary', "havn't", 'even', 'started', 'yet!'],
#  ['wow,',
#   'great',
#   'ohio',
#   'poll.',
#   'shows',
#   'leading',
#   '5',
#   'points,',
#   'beating'],
#  ['thank',
#   'trump',
#   '35%',
#   'kasich',
#   '17%',
#   'cruz',
#   '12%',
#   'rubio',
#   '12%',
#   'carson',
#   '9%'],
#  ['great',
#   'poll!',
#   'thank',
#   'north',
#   '3/15!',
#   'trump',
#   'cruz',
#   '18%',
#   'rubio',
#   '18%',
#   'carson',
#   '10%',
#   'kasich',
#   '7%',
#   'via',
#   '@surveyusa'],
#  ['thank',
#   'illinois!',
#   'great',
#   'news!',
#   '3/15!',
#   'trump',
#   'cruz',
#   '15%',
#   'rubio',
#   'kasich',
#   '13%',
#   'bush',
#   '8%',
#   'carson'],
#  ['failing', '@wsj', 'wall', 'street', 'journal', 'pollster', 'paper'],
#  ['.@foxnews', '@wsj', 'phony', 'poll', 'joke!'],
#  ['new',
#   'cbs',
#   'national',
#   'poll',
#   '-',
#   'massive',
#   'lead',
#   'trump.',
#   'wall',
#   'street',
#   'poll',
#   'total',
#   'wonder',
#   'wsj'],
#  ['love',
#   'south',
#   'carolina.',
#   'leading',
#   'big',
#   'state',
#   '-',
#   'big',
#   'make',
#   'america',
#   'great',
#   'again!'],
#  ['usa',
#   'national',
#   'poll,',
#   'lead',
#   'big',
#   'numbers,',
#   'shows',
#   'head',
#   'head',
#   'beat',
#   'hillary'],
#  ['amazing',
#   'lead',
#   'big',
#   'numbers',
#   'new',
#   'q',
#   'usa',
#   'polls,',
#   'press',
#   'wants',
#   'report',
#   'phony',
#   'wsj/nbc',
#   'poll.'],
#  ['jeb', 'bush', 'got', 'got', 'wants', 'far', '1%', 'nevada!'],
#  ['nevada', 'poll', 'shows', 'jeb', 'bush', 'take', 'dumb', 'go'],
#  ['new',
#   'ppp',
#   'poll',
#   '-',
#   'trump',
#   'rubio',
#   'bush',
#   'debate',
#   'results,',
#   'even'],
#  ['new', 'south', 'carolina', 'poll', 'thank', 'you!'],
#  ['wow,', 'new', 'cbs', 'poll', 'went', 'way', 'thank', 'you!'],
#  ['even',
#   'though',
#   'every',
#   'poll,',
#   'time,',
#   'drudge',
#   'winning',
#   'debate',
#   '@foxnews',
#   'puts',
#   'negative',
#   'people',
#   'biased',
#   '-',
#   'total',
#   'joke!'],
#  ['see', 'beat', 'poll?', '#gopdebate'],
#  ['winning',
#   'debate',
#   'drudge,',
#   'time,',
#   'etc.',
#   'dopey',
#   'charles',
#   'still',
#   'nasty.',
#   'zero',
#   'totally'],
#  ['reports', 'many', 'voters', 'cruz', 'people', 'back', 'dishonest', 'me.'],
#  ['showing',
#   'best',
#   'win',
#   'general',
#   'election.',
#   'states',
#   'never',
#   'me.',
#   'great!'],
#  ['latest',
#   'umass',
#   'tracking',
#   'poll.',
#   'nh',
#   'trump',
#   'rubio',
#   '14',
#   '(-1)',
#   'cruz',
#   '13',
#   '(-1)',
#   'jeb',
#   '10',
#   'kasich',
#   '10'],
#  ['taking', 'new', 'now.', 'amazing', 'new', 'umass', 'poll,', 'nice!'],
#  ['ted', 'cruz', 'win', 'iowa,', 'got', 'far', 'bad!'],
#  ['@clewandowski_:',
#   'trump',
#   'winning',
#   'latino',
#   'poll',
#   'says',
#   '|',
#   'new',
#   'post'],
#  ['ted',
#   'cruz',
#   'totally',
#   'even',
#   'gets',
#   'run',
#   'big',
#   'hillary.',
#   'beat',
#   'hillary',
#   'easily!',
#   'win!'],
#  ['thank',
#   'you!',
#   'michigan',
#   'poll',
#   'finds',
#   'trump',
#   'holds',
#   'lead',
#   'closest',
#   'trump',
#   'clinton',
#   '43%'],
#  ['great', 'poll-', 'even', 'thank', 'you!', '#gopdebate'],
#  ['good',
#   'morning',
#   'america!',
#   'thank',
#   'support',
#   'latest',
#   'drudge',
#   'poll!'],
#  ['biased',
#   'charles',
#   '@foxnews',
#   'flunky',
#   'know',
#   'every',
#   'debate,',
#   'last',
#   'one.',
#   'check',
#   'polls!'],
#  ['poll', 'trump', 'cruz', 'carson', 'rubio', 'jeb'],
#  ['new',
#   '@nbcnews',
#   'wsj',
#   'poll',
#   'shows',
#   '@realdonaldtrump',
#   'pulling',
#   'ahead',
#   '@tedcruz',
#   'great!'],
#  ['"@realdonaldtrump', 'hits', 'new', 'national', 'poll'],
#  ['"donald', 'trump', 'national', 'lead', 'new', 'abc', 'poll'],
#  ['"@realdonaldtrump',
#   '&amp;',
#   '@hillaryclinton',
#   'leading',
#   'w/',
#   'one',
#   'week',
#   '#iowacaucus',
#   '2016',
#   'tonight',
#   '@foxbusiness'],
#  ['cruz', 'going', 'like', 'never'],
#  ['ted', 'cruz', 'nervous', 'poll', 'way', 'down!'],
#  ['poll', 'thank', 'you!', '#trump2016', '#makeamericagreatagain'],
#  ['fox',
#   'news',
#   'poll',
#   'thank',
#   'you,',
#   'new',
#   'hampshire!',
#   '#fitn',
#   '#trump2016'],
#  ['new',
#   'fox',
#   'news',
#   'poll',
#   'thank',
#   'you,',
#   'iowa!',
#   '#trump2016',
#   '#iacaucus'],
#  ['ted', 'cruz', 'poll', 'numbers', 'born', 'many', 'believe', 'cannot'],
#  ['ted',
#   'cruz',
#   'went',
#   'big',
#   'released',
#   'reuters',
#   'poll',
#   '-',
#   'going',
#   'loans'],
#  ['received', 'new', 'fox', 'poll.', 'thank', 'you,', 'america!', '#trump2016'],
#  ['wow!',
#   'new',
#   'national',
#   'zogby',
#   'poll',
#   'cruz',
#   'rubio',
#   'big',
#   'numbers.'],
#  ['leaving',
#   'nevada',
#   'iowa.',
#   'things',
#   'looking',
#   'good',
#   '-',
#   'great',
#   'new',
#   'polls!'],
#  ['new', 'national', 'zogby', 'poll', '#makeamericagreatagain', '#trump2016'],
#  ['new',
#   'reuters',
#   'poll!',
#   'thank',
#   'you!',
#   '#makeamericagreatagain',
#   '#trump2016'],
#  ['spending', '@jebbush', 'bottom', 'polls.', 'use', 'low', 'energy'],
#  ['poll:', 'trump', 'support', 'florida', 'rubio', 'bush', 'combined.'],
#  ['new',
#   'new',
#   'hampshire',
#   'poll',
#   'released.',
#   'thank',
#   'you!',
#   '#fitn',
#   '#trump2016'],
#  ['released',
#   'poll',
#   'increased',
#   'lead',
#   '4',
#   'points',
#   'since',
#   'last',
#   'poll',
#   'cruz'],
#  ['way',
#   'iowa-',
#   'received',
#   'new',
#   'national',
#   'poll',
#   'numbers.',
#   'thank',
#   'you!',
#   '#makeamericagreatagain',
#   '#trump2016'],
#  ['wow,', 'new', 'trump', 'cruz', '-', 'nervous'],
#  ['ted', 'cruz', 'falling', 'polls.', 'people', 'place', 'report', 'loans'],
#  ['wsj/nbc',
#   'poll:',
#   'donald',
#   'trump',
#   'widens',
#   'lead',
#   'republican',
#   'presidential',
#   'race.',
#   '#trump2016'],
#  ['thank',
#   'you,',
#   'iowa!',
#   'highly',
#   'respected',
#   '@oann',
#   'poll',
#   'released.',
#   '#votetrump',
#   '#iowacaucus'],
#  ['reuters', 'trump', '39%,', 'cruz', 'bush', 'carson', 'rubio'],
#  ['beating', 'hillary', 'clinton.', 'race', 'highest', 'get', 'new'],
#  ['found',
#   '@tedcruz',
#   'spending',
#   'fortune',
#   'iowa',
#   'negative',
#   'me.',
#   'nice,',
#   'new',
#   'great.'],
#  ['new', 'cbs', 'poll.', '#trump2016'],
#  ['another',
#   'new',
#   'iowa',
#   'poll',
#   'released.',
#   'thank',
#   'you!',
#   '#iacaucus',
#   '#fitn'],
#  ['new',
#   'iowa',
#   'poll.',
#   'thank',
#   'you!',
#   '#makeamericagreatagain',
#   '#trump2016'],
#  ['heading', 'big', 'good', 'poll', 'over!'],
#  ['@foxnews',
#   'poll,',
#   'easily',
#   'beat',
#   'hillary',
#   'clinton',
#   '-',
#   "havn't",
#   'even',
#   'yet.',
#   'make',
#   'america',
#   'great',
#   'again!'],
#  ['poll', '-', 'thank', 'you!', '#makeamericagreatagain', '#trump2016'],
#  ['@jebbush', 'key', 'state', 'florida', 'poll:', 'trump', 'beats'],
#  ['new',
#   'hampshire.',
#   'received',
#   'great',
#   'news',
#   'reuters',
#   'poll.',
#   'thank',
#   'support!'],
#  ['.@jebbush',
#   'low',
#   'energy',
#   'special',
#   'interest',
#   'money',
#   'many',
#   'people',
#   'ahead',
#   'polls.'],
#  ['nevada',
#   'poll:',
#   'donald',
#   'trump',
#   'ted',
#   'cruz',
#   'marco',
#   'rubio',
#   'via',
#   'great',
#   'news!'],
#  ['people', '@jebbush', 'low', 'big', '$', 'hit', 'ads', 'me!'],
#  ['.@jebbush',
#   'spent',
#   'bottom',
#   'polls.',
#   'spent',
#   'almost',
#   'nothing',
#   'win!'],
#  ['great', 'poll-', 'thank', 'nevada!', '#makeamericagreatagain', '#trump2016'],
#  ['new', 'thank', 'america!', '#makeamericagreatagain', '#trump2016'],
#  ['@jebbush', '@ananavarro', 'two', 'people', 'politics,', '@cnn', 'yet', '39'],
#  ['people',
#   'said',
#   'run,',
#   'lead',
#   'well',
#   'place',
#   'leading',
#   'say',
#   'beat',
#   'hillary.'],
#  ['failed', 'candidate', '@jebbush', 'said', 'came', 'spent'],
#  ['@chucktodd',
#   'dishonest',
#   'showing',
#   'new',
#   '@cnn',
#   'poll',
#   '39%,',
#   'higher'],
#  ['@chucktodd',
#   'using',
#   'much',
#   '@cnn',
#   'poll',
#   'well',
#   'instead',
#   'q',
#   'poll?',
#   'cnn',
#   'even'],
#  ['wow,',
#   'even',
#   'rand',
#   'paul',
#   'past',
#   '@jebbush',
#   'new',
#   '@cnn',
#   'poll.',
#   'jeb',
#   "i'm",
#   'money'],
#  ['mention', 'cnn', 'poll', 'leading', 'cruz', '39'],
#  ['hard',
#   'believe',
#   'winning',
#   'much',
#   'media.',
#   'new',
#   '@cnn',
#   'poll',
#   'amazing',
#   'lead'],
#  ['.@foxnews',
#   'using',
#   'old',
#   'quinnipiac',
#   'poll',
#   'much',
#   'lead',
#   '@cnn',
#   'poll.'],
#  ['big',
#   'news',
#   '-',
#   'new',
#   '@cnn',
#   'poll',
#   'trump',
#   '39',
#   'leads',
#   'every',
#   'major',
#   'way',
#   'cruz',
#   'carson',
#   '10',
#   'rubio',
#   '10'],
#  ['wow,',
#   'new',
#   'reuters',
#   'poll',
#   'out.',
#   'big',
#   'lead',
#   'want',
#   'make',
#   'america',
#   'great',
#   'again!',
#   'trump',
#   '37',
#   'cruz',
#   '11',
#   'top'],
#  ['@jebbush',
#   'donald',
#   'year.',
#   'dominates',
#   'polls,',
#   'news,',
#   'talk',
#   'shows',
#   '&amp;',
#   'social',
#   'media.'],
#  ['well', "i'm", '42%', 'know', 'jeb', 'started', 'keep'],
#  ['online', 'trump', '@realdonaldtrump'],
#  ['want', '@realdonaldtrump,', 'trump'],
#  ['.@jebbush', 'said', 'want', 'talk', "can't", 'win!'],
#  ['great',
#   'poll',
#   'illinois!',
#   'thank',
#   'you!',
#   '#makeamericagreatagain',
#   '#trump2016'],
#  ['.@jebbush',
#   'terrible',
#   'face',
#   'nation',
#   'today.',
#   '2%',
#   'falling',
#   'totally'],
#  ['@realdonaldtrump', 'dominates', 'latest', 'polls,', 'talk', 'sunday'],
#  ['thank',
#   'america!',
#   '@foxnews',
#   'post-debate',
#   'poll',
#   'poll.',
#   '#votetrump2016',
#   '#makeamericagreatagain'],
#  ['new', 'poll:', "trump's", 'massive', 'lead', 'post-debate', 'poll'],
#  ['another',
#   'new',
#   'post-debate',
#   'poll.',
#   'thank',
#   'you!',
#   '#votetrump2016',
#   '#makeamericagreatagain'],
#  ['new',
#   'reuters',
#   'poll',
#   '-',
#   'thank',
#   'you!',
#   '#makeamericagreatagain',
#   '#trump2016'],
#  ['trump', 'first', 'place', '27', 'points.'],
#  ['thank', 'you,', 'many', 'people', 'winning', 'debate', 'last', 'night.'],
#  ['highly',
#   'respected',
#   'public',
#   'policy',
#   'polling',
#   'announced',
#   'number',
#   'one',
#   'iowa.',
#   'thank',
#   'you!'],
#  ['new',
#   'ppp',
#   'poll',
#   'released',
#   'iowa-',
#   '6',
#   'points',
#   'last',
#   'poll.',
#   'leading',
#   'w/',
#   '-',
#   'media',
#   'report',
#   'it!'],
#  ['every',
#   'debate',
#   'far',
#   'according',
#   'debate',
#   'including',
#   '@time',
#   'more.',
#   'bad',
#   'dopey',
#   '@megynkelly'],
#  ['.@megynkelly', 'bad', 'totally', 'cruz', 'new', 'monmouth', 'poll'],
#  ['.@megynkelly,',
#   'hard',
#   'explain',
#   'away',
#   'new',
#   'monmouth',
#   'poll',
#   '14',
#   '27',
#   'lead.',
#   'said'],
#  ['anyone',
#   'using',
#   '@cnn',
#   'iowa',
#   'poll',
#   'big',
#   'lead.',
#   'want',
#   'use',
#   'one',
#   'negative',
#   'poll',
#   'press'],
#  ['amazing',
#   '@cnn',
#   'fortune',
#   'iowa',
#   'poll,',
#   'shows',
#   'first',
#   'place',
#   'cruz',
#   '33%',
#   '20%',
#   '-',
#   'use'],
#  ['wow,',
#   'two',
#   'good',
#   'iowa',
#   'national',
#   'poll',
#   '@abc',
#   '@washingtonpost',
#   '-',
#   'make',
#   'america',
#   'great',
#   'again!'],
#  ['@cnn', 'use', '#cnn', 'iowa', 'poll?', '@andersoncooper'],
#  ['donald',
#   'trump',
#   'hits',
#   '41%',
#   'new',
#   'monmouth',
#   'national',
#   'poll,',
#   'highest',
#   'national',
#   'support',
#   'election',
#   'yet.'],
#  ['new',
#   'national',
#   'poll',
#   'monmouth',
#   '@realdonaldtrump',
#   'trump',
#   'leads',
#   'pack',
#   'ted',
#   'marco',
#   '&amp;',
#   '…'],
#  ['breaking',
#   '@realdonaldtrump',
#   'surging',
#   'ahead',
#   'race',
#   '-',
#   '41%',
#   'new',
#   'national',
#   'poll,',
#   '27%',
#   'ahead'],
#  ['@foxnews',
#   'new',
#   'iowa',
#   '@cnn',
#   'poll',
#   '33%',
#   '20%',
#   'lead',
#   'ted',
#   'cruz',
#   'think',
#   'it!'],
#  ['"@jpmorgan2016:',
#   'trump',
#   'poll',
#   'real',
#   'poll,',
#   'every',
#   'state.',
#   'media',
#   'get'],
#  ['good',
#   'street',
#   'journal',
#   'poll',
#   'released',
#   'went',
#   'last',
#   'month',
#   'lead.',
#   'nice!'],
#  ['"@jpmorgan2016:',
#   '@realdonaldtrump',
#   'trump',
#   'winning',
#   'much',
#   '60%',
#   'nationally.',
#   'biased'],
#  ['interviewed',
#   '@cnn',
#   '9:00',
#   'a.m.',
#   'fox',
#   'news',
#   'sunday',
#   'chris',
#   'a.m.',
#   'cnn',
#   'iowa',
#   'poll',
#   'point',
#   'lead!'],
#  ['new',
#   'cnn',
#   'iowa',
#   'poll',
#   '---',
#   'trump',
#   'cruz',
#   'everyone',
#   'else',
#   'way',
#   'down!',
#   'trust',
#   'register',
#   'poll-',
#   'biased',
#   'trump!'],
#  ['thank', 'you!', '35%', 'new', 'reuters', 'poll', '#2', 'coming', 'time'],
#  ['great', 'news', 'georgia!', 'poll', 'shows', 'first'],
#  ['iowa,',
#   'leading',
#   'big',
#   'new',
#   '@cnn',
#   'poll.',
#   'win',
#   'iowa.',
#   'also,',
#   'beat',
#   'hillary',
#   'easily!'],
#  ['"@foxnews:',
#   'time',
#   'republican',
#   'establishment',
#   'fact',
#   'trump',
#   'lead',
#   'real'],
#  ['respected',
#   'morning',
#   'consult',
#   'poll',
#   'out.',
#   'lead',
#   'beat',
#   'hillary',
#   'head',
#   'head',
#   'wide'],
#  ['establishment',
#   'flunky',
#   'going',
#   'crazy',
#   'released',
#   'cbs',
#   'poll',
#   'way',
#   'new',
#   'fox',
#   'poll',
#   'beating',
#   'hillary.'],
#  ['wow,', 'poll', 'numbers', 'announced', 'gone'],
#  ['last',
#   'hillary',
#   'clinton',
#   'wants',
#   'run',
#   'donald',
#   'trump.',
#   'beating',
#   'every',
#   'state.',
#   'new',
#   'fox'],
#  ['failing',
#   'mention',
#   'new',
#   '@cnn',
#   'poll',
#   'leading',
#   'iowa',
#   'massive',
#   '13',
#   'points',
#   '-',
#   'sad!'],
#  ['great',
#   'poll',
#   'numbers',
#   'coming',
#   'new',
#   'hampshire.',
#   'big',
#   'lead',
#   'according'],
#  ['great', 'new', 'poll', 'nh.', 'thank', 'you!', 'need', 'keep', '#trump2016'],
#  ['big', 'poll', 'coming', '6', 'new', 'hampshire.'],
#  ['new', 'poll', 'supporters', '&amp;', 'ran'],
#  ['@wsj',
#   'wall',
#   'street',
#   'journal',
#   'reported',
#   '@cnn',
#   'iowa',
#   'poll',
#   'lead',
#   'wide',
#   'points,',
#   'going',
#   'big!'],
#  ['iowa',
#   '@cnn',
#   'poll',
#   'trump',
#   '33%',
#   'cruz',
#   '20%',
#   'rubio',
#   '@wsj',
#   'reported',
#   'nothing',
#   'fact',
#   'easily'],
#  ['new',
#   'iowa',
#   'poll',
#   'finds',
#   '.@realdonaldtrump',
#   'lead',
#   'double',
#   'digits.',
#   'https://t.co/00phdhsb37'],
#  ['today,',
#   'iowa',
#   'poll',
#   'finds',
#   'trump',
#   'lead',
#   'double',
#   'https://t.co/00phdhsb37'],
#  ['released',
#   '@cnn',
#   'poll',
#   'gives',
#   'big',
#   '13',
#   'point',
#   'lead',
#   'iowa.',
#   'change',
#   'failing',
#   'thank',
#   'iowa!'],
#  ['tremendous', 'support', 'received', 'iowa', 'cnn', 'poll.', 'thank', 'you!'],
#  ['results', 'cnn', 'poll', 'iowa.', 'believe', 'results', 'even', 'better'],
#  ['poll', 'numbers', 'go', 'even', '@realdonaldtrump'],
#  ['donald',
#   'trump',
#   'lead',
#   'national',
#   'poll',
#   '#makeamericagreatagain',
#   '#wakeupamerica'],
#  ['.@cnn', '&amp;', '@cnnpolitics', 'thank', 'john', 'new', 'cnn', 'poll.'],
#  ['.@cnn',
#   'poll',
#   'came',
#   'out,',
#   'amazing',
#   'numbers',
#   'want',
#   'make',
#   'america',
#   'great',
#   'again!',
#   'trump',
#   'point',
#   'lead',
#   '2nd'],
#  ['7', 'points', 'last', 'trump', 'dominating', 'lead'],
#  ['@realdonaldtrump', 'poll', 'numbers', 'jump', 'every', 'time', 'like'],
#  ['beat',
#   'hillary',
#   'new',
#   '@foxnews',
#   'poll',
#   'head',
#   'head.',
#   'strength',
#   'make',
#   'america',
#   'great',
#   'again!'],
#  ['think', 'paper', 'like', 'post', 'fair', 'record,', 'almost'],
#  ['republican',
#   'concerned',
#   'w/',
#   'high',
#   'poll',
#   'concerned',
#   'beat',
#   'hillary',
#   'up!'],
#  ['pollster',
#   'national',
#   'average',
#   'national',
#   '&amp;',
#   'pollsters.',
#   '#makeamericagreatagain',
#   '#trump2016'],
#  ['donald',
#   'trump',
#   'rises',
#   '38%',
#   'nationally;',
#   'ted',
#   'cruz',
#   '2nd',
#   '12%'],
#  ['great', 'new', 'poll', 'numbers!', 'thank', 'support!', '#trump2016'],
#  ['new',
#   '@oann',
#   'national',
#   'poll',
#   'released.',
#   'thank',
#   'america!',
#   '#trump2016'],
#  ['great',
#   'poll',
#   'numbers!',
#   'thank',
#   'you!',
#   '#makeamericagreatagain',
#   '#trump2016'],
#  ['great',
#   'poll',
#   'numbers',
#   'beating',
#   'hillary',
#   'clinton',
#   'one',
#   'one.',
#   'thank',
#   'you!'],
#  ['big',
#   'new',
#   '@abc',
#   'poll',
#   'announced',
#   '9:00',
#   'a.m.',
#   'week',
#   'interviewed'],
#  ['announced', 'leading', 'big', 'new', '@abc', 'poll', 'week', '9:00', 'a.m.'],
#  ['donald', 'trump', 'lead', 'race;', 'ted', 'cruz', 'makes', 'poll:', 'via'],
#  ['@clewandowski_:',
#   '.@realdonaldtrump',
#   'extends',
#   'lead',
#   'reuters',
#   '#gop',
#   'poll.',
#   '#makeamericagreatagain',
#   '#trump2016'],
#  ['john', 'despite', 'governor', 'losing', 'ohio', 'polls.'],
#  ['new',
#   'hampshire',
#   'poll:',
#   '@realdonaldtrump',
#   'race',
#   'new',
#   'trump',
#   'rubio',
#   'cruz',
#   '11,',
#   'bush',
#   '9,',
#   'carson',
#   '9,',
#   '&amp;',
#   'kasich'],
#  ['via', '"trump', 'extends', 'lead', 'new', 'hampshire', 'poll"'],
#  ['great', 'new', 'poll'],
#  ['many',
#   'great',
#   'like',
#   'reuters',
#   '-',
#   'big',
#   'leads',
#   'everywhere.',
#   'new',
#   'hampshire',
#   'really',
#   'win',
#   'big',
#   'make',
#   'america',
#   'great',
#   'again!'],
#  ['great',
#   'poll',
#   'numbers',
#   'thank',
#   'you!',
#   '#trump2016',
#   '#makeamericagreatagain'],
#  ['donald',
#   'trump',
#   'surges',
#   'poll',
#   'among',
#   'likely',
#   'republican',
#   'voters'],
#  ['poll:',
#   'trump',
#   'surges',
#   '42%',
#   'nationally;',
#   'news',
#   'marco',
#   '@realdonaldtrump"',
#   'great',
#   'news!'],
#  ['great',
#   'news',
#   'new',
#   'hampshire!',
#   'pulling',
#   'away',
#   'pack',
#   'w/',
#   '2nd',
#   '17%',
#   'behind',
#   '#trump2016'],
#  ['"@drudge_report:',
#   'reuters',
#   'poll:',
#   'trump',
#   'carson',
#   'rubio',
#   'cruz',
#   'thank',
#   '-',
#   'great',
#   'honor!'],
#  ['2%', '27%', '-', 'jump', 'first'],
#  ['on-line',
#   'polls,',
#   'including',
#   'drudge',
#   'time,',
#   'said',
#   'debate.',
#   '@krauthammer',
#   'said'],
#  ['loved', 'drudge', 'on-line', 'polls!', 'amazing', 'job.'],
#  ['@cnn', '@abc', 'doubt', 'carson', 'drop', 'polls."'],
#  ['voting', 'trump!'],
#  ['nice', 'next', 'done', 'good', 'reporting!'],
#  ['great', '4', '@oann', '#trump'],
#  ['lead', 'reuters', 'national', 'poll'],
#  ['interesting',
#   'presidential',
#   'race;',
#   'carson',
#   'beat',
#   '@realdonaldtrump',
#   'beats',
#   'carson',
#   'polls!'],
#  ['great',
#   'honor',
#   'easily',
#   'first',
#   '@foxnews',
#   'poll',
#   'even',
#   'though',
#   'best',
#   'used',
#   'winner!'],
#  ["who's", 'ahead', 'race.', 'trump', 'leading', 'polls.'],
#  ['@realdonaldtrump',
#   'poll',
#   'numbers',
#   'higher',
#   'one',
#   'democrats',
#   'voting'],
#  ['wow!', '@foxnews', 'poll', 'came', 'out.', '#1', 'almost', '#trump2016'],
#  ['terrible', '@megynkelly', 'used', 'poll', 'used', 'use', 'up?'],
#  ['@realdonaldtrump', 'news', 'trump', 'ahead', 'leaving', 'others', 'doubt'],
#  ['@realdonaldtrump',
#   'trust',
#   '@oann',
#   'really',
#   'fair',
#   'really',
#   'iowa',
#   'lead!'],
#  ['latest',
#   'poll',
#   'florida',
#   'voters',
#   'shows',
#   'lead',
#   'trump!',
#   "he'd",
#   'beat'],
#  ['.@megynkelly', 'used', 'poll', 'else', 'use', 'i’m', 'up?'],
#  ['use', 'new', 'instead', 'national', 'poll', 'dishonest', 'reporting!'],
#  ['online', 'poll:', '@realdonaldtrump', 'handle', 'far', 'true,'],
#  ['marco',
#   'debate',
#   'people.',
#   'every',
#   'on-line',
#   'poll,',
#   'even',
#   'crazy',
#   '@cnbc.',
#   'marco',
#   'good'],
#  ['thank', 'nice,', 'true,', 'leading', 'new', 'hampshire', '@foxnews'],
#  ['trump', 'leads', 'carson', 'rubio', 'poll'],
#  ['@realdonaldtrump',
#   '#makeamericagreatagain',
#   'leading',
#   'big',
#   'nationwide',
#   'reuters',
#   'poll',
#   '-',
#   'great!'],
#  ['thank', '@wsj', 'nice', 'said', 'debate', 'except', 'nbc', 'explain'],
#  ['@realdonaldtrump', 'surges', 'post-debate', 'poll!', 'trump', 'puts', 'us'],
#  ['new',
#   'nbc',
#   'poll',
#   'first',
#   'place',
#   'said',
#   'third',
#   'debate',
#   '-',
#   'every',
#   'poll',
#   '#1.'],
#  ['democrats', 'say', 'donald', 'trump', 'hillary', 'clinton'],
#  ['@realdonaldtrump',
#   'republican',
#   'support',
#   'carson',
#   'poll',
#   'used',
#   '@megynkelly',
#   'last',
#   'month'],
#  ['everyone', '10%', 'drop', 'support', 'trump', '@realdonaldtrump', 'great'],
#  ['donald', 'trump', 'leads', 'florida'],
#  ['thank',
#   '@cnn',
#   '@andersoncooper',
#   'many',
#   'others',
#   'leading',
#   'almost',
#   'national',
#   '&amp;',
#   'state',
#   'polls.'],
#  ['loved', 'debate', 'last', '@cnbc.', 'check', 'polls!', 'everyone'],
#  ['interview', 'increase', 'sunday', 'last', 'year.', '20%', 'last'],
#  ['cnbc',
#   'poll:',
#   'trump',
#   '#gopdebate',
#   '#makeamericagreatagain',
#   '#trump2016'],
#  ['"@drudge_report:', 'trump', 'wins', 'cnbc', 'rubio'],
#  ['@realdonaldtrump', 'leading', 'polls."'],
#  ['said', '@realdonaldtrump', '#gop', 'debate'],
#  ['@oann', 'gravis', 'marketing', 'poll', '@realdonaldtrump', 'great!'],
#  ['#trump',
#   'came',
#   'clear',
#   'winner',
#   'yet',
#   'again!',
#   'next',
#   '#gopdebate',
#   'need',
#   '5',
#   'many'],
#  ['#cnbcgopdebate',
#   'poll',
#   'closed',
#   '#trump2016',
#   'declared',
#   'official',
#   'winner.'],
#  ['@realdonaldtrump',
#   'showing',
#   'next',
#   'tremendous',
#   'debate.',
#   'winning',
#   'post',
#   'debate',
#   'polls.'],
#  ['drudge', 'poll', 'thank', 'you!'],
#  ['thank', 'honor', 'win', '@nbc', '#gopdebate', 'poll.'],
#  ['#cnbcgopdebate',
#   'poll',
#   'closed',
#   '#trump2016',
#   'declared',
#   'official',
#   'winner.',
#   'thank',
#   'you!'],
#  ['thanks', 'said', 'debate.', 'even', '@cnbc', 'poll!'],
#  ['via', '"trump', 'still', 'lead', '14', 'points', 'put', 'carson'],
#  ['@cnbc', 'poll', 'trump', 'carson', 'rubio'],
#  ['poll,', 'one', 'highly', 'released.', 'wow,', 'media', 'numbers', '-'],
#  ["i'm",
#   'media',
#   'report',
#   'highly',
#   'respected',
#   'new',
#   'national',
#   'poll',
#   'came',
#   'via'],
#  ['@realdonaldtrump', '@cnbc', 'get', 'trump', 'going', 'one', 'run'],
#  ['@cnbc', 'poll', 'numbers', 'carson', '-', 'establishment', 'win'],
#  ['think', '@cnbc', 'get', 'polling', 'numbers', 'debate.', 'sad!'],
#  ['continues',
#   'report',
#   'poll',
#   'numbers.',
#   'number',
#   'based',
#   'every',
#   'trump',
#   'wide',
#   "can't",
#   'say',
#   'it!'],
#  ['debate', 'behind', 'national', 'lead', 'trump', '35.6%', 'carson'],
#  ['@realdonaldtrump',
#   'lot',
#   'people',
#   'know',
#   'voting',
#   'trump',
#   'none',
#   'lead',
#   'bigger',
#   'anyone'],
#  ['out,', 'poll', 'north', 'carolina.', '#trump2016', '#makeamericagreatagain'],
#  ['national', 'poll', '#makeamericagreatagain', '#trump2016'],
#  ['@oann',
#   'great',
#   'job.',
#   'u',
#   'r',
#   'best',
#   'pick',
#   '&amp;',
#   'ohio',
#   'u',
#   'r',
#   'leading',
#   'too"'],
#  ['national',
#   'presidential',
#   'poll',
#   'via',
#   '@oann',
#   '@realdonaldtrump',
#   '35.6%',
#   '#trump2016'],
#  ['national',
#   'lead',
#   'increases',
#   '35.6%',
#   'going',
#   'third',
#   'debate',
#   'trump,',
#   'carson',
#   '…'],
#  ['new',
#   'gravis',
#   'national',
#   'poll',
#   '---',
#   'nice!',
#   '#makeamericagreatagain'],
#  ['@foxbusiness',
#   '@realdonaldtrump',
#   'post',
#   'trump',
#   '40',
#   'percent',
#   'carson'],
#  ['new',
#   'poll',
#   'shows',
#   '@realdonaldtrump',
#   '@realbencarson',
#   'tied',
#   '#gop',
#   'field',
#   'iowa.'],
#  ['leaving',
#   'new',
#   'hampshire',
#   'now.',
#   '@todayshow',
#   '7:00',
#   'a.m.',
#   'new',
#   '@cbsnews',
#   'poll',
#   'new',
#   'trump',
#   'carson'],
#  ['@byronyork',
#   'latest',
#   'poll',
#   'shows',
#   'donald',
#   'trump',
#   'winning',
#   'hillary'],
#  ['@realdonaldtrump',
#   '@byronyork',
#   '@cbsnews',
#   '@cnn',
#   'way',
#   'ahead',
#   'matter.',
#   'trump'],
#  ['great',
#   'numbers',
#   '@cbsnews',
#   'poll.',
#   'also',
#   'post',
#   'poll.',
#   'thank',
#   'you!',
#   '@cnn'],
#  ['believe',
#   '@foxnews',
#   'still',
#   'old',
#   'iowa',
#   'poll',
#   'numbers',
#   'mention',
#   'post',
#   'cbs',
#   'results?'],
#  ['poll',
#   '-',
#   'wow!',
#   'new',
#   'hampshire',
#   'trump',
#   '38%',
#   'carson',
#   '12%',
#   'bush',
#   '8%',
#   'south',
#   'carolina',
#   'trump',
#   '40%',
#   'carson',
#   'cruz',
#   '8%',
#   'iowa',
#   'trump',
#   '27%',
#   'carson',
#   '27%'],
#  ['watch',
#   'interview',
#   '@cbsnews',
#   'face',
#   'nation',
#   'also,',
#   'new',
#   'cbs',
#   'good',
#   'media'],
#  ['big', 'poll', 'face', 'nation'],
#  ['big',
#   'poll',
#   'announced',
#   'morning',
#   '@cbsnews',
#   'face',
#   'wonder',
#   'well',
#   'press',
#   'report',
#   'results?',
#   'doubt'],
#  ['donald', 'trump', 'tops', 'poll', 'state', 'great', 'news'],
#  ['donald',
#   'trump',
#   'leads',
#   'shows',
#   'strength',
#   '-',
#   'abc',
#   'news',
#   '-',
#   'via'],
#  ['national', 'poll', 'donald', 'trump', 'continues', 'field', 'last'],
#  ['new', 'poll', 'shows', '.@realdonaldtrump', 'likely', 'win', 'nomination.'],
#  ['@johnrobertsfox:',
#   'new',
#   'poll',
#   'shows',
#   '@realdonaldtrump',
#   'commanding',
#   'lead',
#   '-',
#   '10',
#   'points',
#   'closest'],
#  ['@johnrobertsfox:',
#   'new',
#   '@washingtonpost',
#   'poll',
#   'finds',
#   'think',
#   '@realdonaldtrump',
#   'likely',
#   'best'],
#  ['new',
#   'poll',
#   'abc',
#   'post',
#   'trump',
#   'carson',
#   'rubio',
#   '10',
#   'bush',
#   '7',
#   'wow,',
#   'media',
#   'put',
#   'negative'],
#  ['@realdonaldtrump', 'beats', '@hillaryclinton'],
#  ['interviewed',
#   '@gma',
#   'good',
#   'morning',
#   'america',
#   '7:00',
#   'a.m.',
#   '@abc',
#   'new',
#   'poll',
#   'numbers.',
#   'make',
#   'america',
#   'great',
#   'again!'],
#  ['out:',
#   'boston',
#   'poll',
#   'trump',
#   '28',
#   'carson',
#   'bush',
#   '9',
#   'rubio',
#   '6',
#   'cruz',
#   '5',
#   'press',
#   'say'],
#  ['donald',
#   'trump',
#   'still',
#   'dominating',
#   'polls,',
#   'debate,',
#   'news,',
#   'nomination'],
#  ['interviewed',
#   '@gma',
#   'good',
#   'morning',
#   'america',
#   '7:00',
#   'a.m.',
#   'big',
#   'new',
#   'abc',
#   'poll',
#   'coming',
#   '-',
#   'hope'],
#  ['@realdonaldtrump',
#   '#trump2016',
#   '#trump',
#   'hits',
#   'highest',
#   'poll',
#   'number',
#   'make',
#   'gains'],
#  ['best',
#   'day',
#   'ever',
#   'polls,',
#   'one',
#   '41%',
#   '-',
#   'morning',
#   'boston',
#   'nbc',
#   'cnn',
#   'great.',
#   'more!'],
#  ['"donald', 'trump', 'tops', 'poll', '28', 'percent'],
#  ['great', 'new'],
#  ['since', 'front-runner', 'public', 'republican', 'party', 'nomination.'],
#  ['new', 'poll:', 'trump', 'support', 'highest', 'since'],
#  ['@jebbush', 'jeb', 'poll', 'even', '@realdonaldtrump"'],
#  ['donald', 'trump', 'far', 'ahead', 'two', 'key', 'state', 'polls.', 'thanks'],
#  ['good',
#   'news',
#   'want',
#   'make',
#   'america',
#   'great',
#   '-',
#   'winning',
#   'every',
#   'poll',
#   'every',
#   'state',
#   'national',
#   '-',
#   'big',
#   'numbers!',
#   'thanks'],
#  ['via', 'business', 'donald', "trump's", 'poll', '2', 'key', 'states'],
#  ['great', 'new'],
#  ['keep', 'great', 'best'],
#  ['also', 'hear', 'megyn', 'say', 'front-runner'],
#  ['every',
#   'poll,',
#   'time,',
#   'drudge,',
#   'slate',
#   'others,',
#   'said',
#   'debates',
#   '-',
#   'megyn',
#   'kelly',
#   'two',
#   'say',
#   'bad',
#   'watch'],
#  ['megyn',
#   'kelly',
#   'two',
#   'really',
#   'dumb',
#   'chris',
#   '&amp;',
#   'say',
#   'debates'],
#  ['cnn', 'poll', 'south', 'carolina', '–', 'great'],
#  ['cnn/orc',
#   'poll',
#   'results',
#   'trump',
#   'carson',
#   'fiorina',
#   'bush',
#   '6,',
#   'cruz',
#   '4'],
#  ['interesting', 'bad', 'taking', 'much', 'time', '-', 'born'],
#  ['"trump', 'tops', 'clinton', 'quinnipiac', 'university', 'poll'],
#  ['.@jebbush',
#   'hope',
#   '.@realdonaldtrump',
#   'another',
#   '10',
#   'points.',
#   '#wakeupamerica'],
#  ['via', 'breitbart', '-', 'high', 'donald', 'trump', 'american', 'south'],
#  ["i'm",
#   'leading',
#   'big',
#   'every',
#   'poll',
#   'going',
#   'win!',
#   'trump',
#   'never',
#   'gives',
#   'up!'],
#  ['great',
#   'gravis',
#   'poll',
#   'great',
#   'state',
#   'nh.',
#   'also,',
#   'watch',
#   'cbs',
#   '&amp;',
#   '--'],
#  ['new', 'gravis', 'poll', 'nh', 'out:', 'trump', '32%,', 'carson', '13%'],
#  ['@realdonaldtrump', 'really', "who's", 'dominating', 'go'],
#  ['packed',
#   'house',
#   'big',
#   'poll',
#   'results',
#   'today,',
#   'leading',
#   'big',
#   'everywhere.',
#   'make',
#   'america',
#   'great',
#   'again!'],
#  ['found', 'republican', 'straw', 'poll', 'fair', 'new', 'hampshire', 'past'],
#  ['.@realdonaldtrump',
#   'leading',
#   '@realbencarson',
#   'new',
#   'quinnipiac',
#   'poll',
#   '@foxbusiness'],
#  ['heading', 'packed', 'house', 'iowa!', 'great', 'poll', 'numbers', 'see'],
#  ['10/6/15', 'reuters', 'poll', 'donald', 'trump', 'continues'],
#  ['@ananavarro',
#   '@cnn',
#   '10/6/15',
#   'morning',
#   'poll',
#   'trump',
#   'trump',
#   'carson',
#   '13',
#   'rubio',
#   '10',
#   'bush',
#   '7',
#   'fiorina'],
#  ['pew',
#   'poll:',
#   '@realdonaldtrump',
#   'holds',
#   'commanding',
#   'lead',
#   '@cnnpolitics'],
#  ['@danscavino', '@realdonaldtrump', 'media', 'trump', 'rises'],
#  ['donald', 'trump', 'maintains', 'huge', 'lead', 'go'],
#  ["i'm",
#   'leading',
#   'big',
#   'margins',
#   'every',
#   'poll',
#   'press',
#   'ever',
#   'get',
#   'out?',
#   "i'm",
#   'going',
#   'win!'],
#  ["trump's",
#   'big',
#   'lead',
#   'new',
#   'poll',
#   "jeb's",
#   'taken',
#   '@megynkelly',
#   'thanks'],
#  ['@drudge_report', '@jebbush', 'jeb', 'falling', 'feel', 'cannot'],
#  ['polling', 'convergence', '-', 'oan/gravis', '#cnn'],
#  ['polling',
#   'convergence',
#   '-',
#   'oan/gravis',
#   'reuters',
#   'donald',
#   'trump',
#   'surging',
#   '-',
#   '35%',
#   'via'],
#  ['donald',
#   'trump',
#   'leads',
#   '9',
#   'points',
#   'pew',
#   'poll',
#   '–',
#   'jeb',
#   'bush',
#   '#tcot'],
#  ['latest', 'finds', '37', 'percent', '@realdonaldtrump', 'leading'],
#  ['debate.'],
#  ['great',
#   'news!',
#   'highly',
#   'respected',
#   'usa',
#   'university',
#   'poll.',
#   'enjoy!'],
#  ['hope',
#   'rand',
#   'paul',
#   'gets',
#   'supporters',
#   'come',
#   'me.',
#   'much',
#   'better',
#   'job'],
#  ['rand', 'paul', 'race'],
#  ['zogby',
#   'poll:',
#   'trump',
#   'widens',
#   'lead',
#   'debate',
#   'http://t.co/yazykwvxnj'],
#  ['trump',
#   'went',
#   'way',
#   'said',
#   "he'd",
#   'take',
#   'money',
#   'us',
#   '2',
#   '2',
#   'social'],
#  ['marco', 'rubio', 'weak', 'poll', 'numbers'],
#  ['poll', 'double', 'digit', 'lead'],
#  ['new',
#   'poll:',
#   '@realdonaldtrump',
#   'maintains',
#   'huge',
#   'lead',
#   'georgia!',
#   '#trump2016'],
#  ['dishonest',
#   'say',
#   'none',
#   'including',
#   '&amp;',
#   'morning',
#   'consult',
#   'matter.'],
#  ['.@megynkelly,',
#   '@foxnews',
#   'poll',
#   'said',
#   'came',
#   'debate.',
#   'others,',
#   'time,',
#   'drudge,',
#   'slate',
#   'etc.',
#   'said',
#   'came'],
#  ['wow,',
#   'really',
#   'nice',
#   'lead',
#   'new',
#   'increase',
#   'since',
#   'last',
#   'poll!'],
#  ['trump', 'leads', 'field'],
#  ['new', 'bloomberg', 'poll:', 'trump', 'leads', 'big'],
#  ['rubio', 'bush', 'florida', 'poll"', '--', 'trump', 'trump', 'rubio', 'bush'],
#  ['morning', 'consult', 'poll:', '"trump'],
#  ['2016',
#   'republican',
#   'primary',
#   'morning',
#   'consult',
#   'poll',
#   'released.',
#   'trump',
#   'carson',
#   'bush',
#   '11,',
#   'fiorina',
#   '6,',
#   'rubio',
#   'cruz',
#   'taken',
#   'debate'],
#  ['@realdonaldtrump', '@foxnews', 'cnn', 'combined.', 'old', 'bush'],
#  ['negative', 'post', 'great', 'came', 'including', '@foxnews', 'good', 'me!'],
#  ['"@alivelutheran:',
#   '@todayshow',
#   'touts',
#   'cnn',
#   'instead',
#   'own!!',
#   'course,',
#   'nbc',
#   'one',
#   'shows',
#   'much',
#   'higher.',
#   'trump',
#   'corrects',
#   'them!'],
#  ['via', 'pollster', '#1'],
#  ['zogby', 'respected', 'business', 'polling', 'media', '@realdonaldtrump"'],
#  ['media',
#   'picked',
#   'new',
#   'zogby',
#   'poll',
#   'put',
#   'out?',
#   'doubt',
#   'it!',
#   'http://t.co/yazykwvxnj'],
#  ['new',
#   'zogby',
#   'highly',
#   'media',
#   'report',
#   'gives',
#   'even',
#   'bigger',
#   'lead!',
#   'http://t.co/yazykwvxnj'],
#  ['"@alivelutheran:',
#   '@todayshow',
#   'touts',
#   'cnn',
#   'instead',
#   'own!!',
#   'course,',
#   'nbc',
#   'one',
#   'shows',
#   'much',
#   'higher.',
#   'trump',
#   'corrects',
#   'them!'],
#  ['thanks', '@nbcnews', 'showing', 'us', 'use', 'poll!', '#trump2016'],
#  ['@todayshow',
#   'use',
#   'poll',
#   'numbers',
#   'massive',
#   'lead',
#   'instead',
#   'used',
#   '@cnn',
#   'numbers',
#   'lead'],
#  ['best', 'poll', 'numbers,', 'also', 'much', 'media', 'totally', 'sad!'],
#  ['leading',
#   'big',
#   'polls,',
#   'two',
#   'today,',
#   '@nbc',
#   'nbc',
#   'poll',
#   'double',
#   '29%.',
#   'fiorina'],
#  ['@nbc', 'new', 'poll', 'numbers.', 'based', 'debate', 'results,'],
#  ['@danscavino:',
#   'check',
#   'latest',
#   'morning',
#   'consult',
#   'poll,',
#   'released',
#   '@realdonaldtrump',
#   '#1',
#   '#trump2016'],
#  ['wow,',
#   'great',
#   'post-debate',
#   'poll:',
#   '"trump',
#   'increases',
#   'via',
#   'breitbart'],
#  ['every',
#   'poll',
#   'done',
#   'debate',
#   'last',
#   'drudge',
#   'newsmax',
#   'time',
#   'winning',
#   'landslide.',
#   '#makeamericagreatagain!'],
#  ['winning', '@drudge_report', 'poll-'],
#  ['really',
#   'looking',
#   'despite',
#   '&amp;',
#   'special',
#   'interest',
#   '$',
#   'spent',
#   'me.',
#   'i’m'],
#  ['like', 'terrible', 'job', 'governor', 'zero', 'polls,', 'allowed', 'debate'],
#  ['many', 'people', 'stage', 'debate.', '2%', 'allowed'],
#  ["trump's", 'going', 'people', 'going', 'love'],
#  ['wow,', 'lightweight', 'governor', 'registered', 'percent', 'polls,'],
#  ['good', 'new', 'quinnipiac', 'poll', 'came', '#1', 'iowa.'],
#  ['people', 'register', '1%', 'polls.', 'never', 'thought'],
#  ['great',
#   'honor',
#   'polling',
#   'numbers',
#   'like',
#   'american',
#   '&amp;',
#   'numbers'],
#  ['poll:', 'trump', 'beats', 'clinton', 'thank', 'you!'],
#  ['presidential',
#   'election',
#   'today,',
#   'according',
#   '@surveyusa',
#   'poll,',
#   'donald',
#   'trump'],
#  ['trump', '40', 'percent', 'poll'],
#  ['first',
#   'place',
#   'lot',
#   'polls,',
#   'tied',
#   'first',
#   'place',
#   'ben',
#   'carson',
#   'one',
#   'iowa',
#   'poll.',
#   'thought'],
#  ['tracking', 'pollster', '#gop'],
#  ['2016', 'nomination', '#1'],
#  ['interviewed', '@gma', 'morning', '7:00.', 'thanks', 'great', 'poll'],
#  ['"@roniseale:', 'big', 'leads', '#trump2016', 'great!'],
#  ['every',
#   'poll',
#   'winning',
#   'listen',
#   'dopey',
#   'trump',
#   'think',
#   "i'm",
#   '@foxnews'],
#  ['yet',
#   'another',
#   'weak',
#   'hit',
#   'candidate',
#   'failing',
#   'jeb',
#   'low',
#   'others',
#   'gone'],
#  ['released',
#   'public',
#   'policy',
#   'polling',
#   '-',
#   'national',
#   'best',
#   'yet.',
#   'make',
#   'america',
#   'great',
#   'again!'],
#  ['-',
#   'new',
#   'ppp',
#   'national',
#   'poll',
#   'first',
#   'place',
#   'wide',
#   'margin',
#   '29%.',
#   'wonder',
#   '@foxnews',
#   'reported',
#   'bad!'],
#  ['leading',
#   'bloomberg',
#   'iowa',
#   'poll.',
#   'also,',
#   'favorability',
#   'numbers',
#   'went',
#   'record,',
#   'almost',
#   'thank',
#   'iowa!'],
#  ['loved', 'many', 'straw', 'poll', 'big!'],
#  ['trump', 'wins', 'party', 'straw', '-', 'newsmax', 'thank', 'you!'],
#  ['via', '"trump', 'wins', 'straw', 'poll'],
#  ['-', 'reports', 'donald', 'trump', 'leading', 'latino', 'via'],
#  ['trump',
#   'breaks',
#   '40%',
#   'gravis',
#   'marketing',
#   'poll.',
#   'leads',
#   'closest',
#   '@danscavino',
#   '#trump2016',
#   'http:…'],
#  ['via', 'trump', 'leads', 'win', 'nomination'],
#  ['interviewed', '@todayshow', 'morning', '7:00.', 'politics,', 'enjoy!'],
#  ['heading', 'iowa', 'packed', 'released', 'polls,', 'first', 'thank', 'you!'],
#  ['@danscavino:',
#   'breaking',
#   'public',
#   'policy',
#   'new',
#   'hampshire!',
#   '@realdonaldtrump',
#   '#trump2016',
#   'http:/…'],
#  ['another',
#   'good',
#   'poll',
#   'great',
#   'state',
#   'trump',
#   'carson',
#   '15%',
#   'bush'],
#  ['got',
#   '4',
#   'points',
#   'state',
#   'better',
#   'zero',
#   'nationally.',
#   'behind',
#   'me.'],
#  ['terrible', 'job', 'governor', 'new', 'ran', 'landslide.', 'graham', 'zero'],
#  ['new',
#   'reuters',
#   'poll',
#   'came',
#   '32%,',
#   'highest',
#   'number',
#   'back',
#   'make',
#   'america',
#   'great',
#   'again!'],
#  ['points', '-', '9%'],
#  ['another', 'great', 'poll', 'thank', 'you!'],
#  ['new',
#   'cnn/orc',
#   'poll:',
#   '@realdonaldtrump',
#   '#1',
#   'w/',
#   '24%',
#   '--',
#   'favorability',
#   'rise',
#   "jeb's",
#   '60%',
#   'among'],
#  ['trump'],
#  ['poll:', '@realdonaldtrump,', '@jebbush', '@realbencarson', 'top'],
#  ['@danscavino:',
#   '2016',
#   'primary',
#   'tracking',
#   '|',
#   '28',
#   'pollsters.',
#   '#1',
#   'trump',
#   '#2',
#   'bush',
#   '#3',
#   'carson',
#   'rubio',
#   'http://t…'],
#  ['@danscavino:',
#   'cnn',
#   'poll',
#   '•',
#   'likely',
#   'change',
#   '@realdonaldtrump',
#   'ben',
#   'carson',
#   'ted',
#   'cruz',
#   'fiorina',
#   'http:/…'],
#  ['really', 'bad'],
#  ['@danscavino:',
#   '2016',
#   'national',
#   'via',
#   'fox',
#   'news',
#   'released',
#   'today.',
#   '@realdonaldtrump',
#   '#1',
#   '#2',
#   '12%',
#   '&amp;',
#   '#3',
#   'http://…'],
#  ['national', '#trump2016', 'leads', 'double', 'digits.', 'back'],
#  ['@danscavino:',
#   'great',
#   'poll',
#   '@realdonaldtrump',
#   '#1',
#   '•',
#   'lead',
#   'higher',
#   '#2',
#   'jeb'],
#  ['cnn/orc', 'poll:', '@realdonaldtrump', 'tops', 'iowa'],
#  ['@danscavino', '@realdonaldtrump', 'poll', 'says', 'trump', 'support', '10%'],
#  ['@danscavino:',
#   'cnn/orc',
#   'poll',
#   '@realdonaldtrump',
#   '#1',
#   '#1',
#   '#1',
#   '35%',
#   '#1',
#   '&amp;',
#   'more!',
#   'http:…'],
#  ['new',
#   '@cnn',
#   'iowa',
#   'poll',
#   'shows',
#   '@realdonaldtrump',
#   'carson',
#   'walker',
#   '9%',
#   'bush',
#   '#iacaucus'],
#  ['@danscavino:',
#   'poll',
#   '#gop',
#   'debate',
#   '&amp;',
#   '2016',
#   '#makeamericagreatagain',
#   '#trump2016'],
#  ['donald',
#   'trump',
#   'maintains',
#   'support',
#   '24%',
#   'republican',
#   'voters',
#   'new',
#   'online',
#   'poll',
#   'margin',
#   'bush'],
#  ['"@katygolf:',
#   '@maxinerunner:',
#   'newsmax',
#   'poll',
#   'http://t.co/ea3gvlbri8',
#   '@realdonaldtrump:',
#   '65%',
#   '@marklevinshow',
#   '@rwsurfergirl"',
#   '@krauthammer'],
#  ['"@katygolf:',
#   '@maxinerunner:',
#   'newsmax',
#   'poll',
#   'http://t.co/ea3gvlbri8',
#   '@realdonaldtrump:',
#   '65%',
#   '@marklevinshow',
#   '@rwsurfergirl"',
#   'another',
#   'debate',
#   'win!'],
#  ['@realdonaldtrump',
#   'breaks',
#   'records',
#   'poll',
#   'support',
#   'quinnipiac',
#   '2',
#   'years'],
#  ['@danscavino:',
#   '#gopdebate',
#   'winner!',
#   'drudge',
#   '@realdonaldtrump',
#   'time',
#   '@realdonaldtrump',
#   '49%',
#   '@realdonaldtrump',
#   'http://t…'],
#  ['@time',
#   'poll:',
#   '@realdonaldtrump',
#   'winner',
#   'last',
#   'debate',
#   'wide',
#   '10%',
#   'http://t.co/mzr62luvwq'],
#  ['time',
#   'poll:',
#   '@realdonaldtrump',
#   'wins',
#   'first',
#   'margin',
#   'http://t.co/mzr62luvwq'],
#  ['@realdonaldtrump',
#   'position',
#   'w/',
#   '52%',
#   '12%',
#   '@drudge_report',
#   'even',
#   '@megynkelly',
#   '&amp;',
#   'tried',
#   'take',
#   'out.'],
#  ['@realdonaldtrump',
#   'tried',
#   'take',
#   '&amp;',
#   'poll',
#   'numbers',
#   'voters',
#   '@foxnews'],
#  ['every',
#   'poll',
#   'debate',
#   'tonight',
#   'massive',
#   'margins',
#   '@drudge_report',
#   '&amp;',
#   '@time',
#   'dumb'],
#  ['nbc', 'says', 'trump', 'leads', 'trump', 'leads', 'too"'],
#  ['trump', 'leading', 'almost', 'every', 'major', 'republican', 'primary'],
#  ['poll:', 'trump', 'leads', 'field', 'among', 'records', 'favorability'],
#  ['trump', 'jeb', 'rubio', 'wsj/nbc', 'news', 'poll', '#tcot'],
#  ['@danscavino:',
#   'new',
#   'hampshire',
#   'poll',
#   'shows',
#   '43%',
#   'say',
#   'feel',
#   '@realdonaldtrump',
#   'best',
#   'handle',
#   '#makeamericagreatagain🇺🇸',
#   'http://t…'],
#  ['donald', 'trump', 'leads', 'debate.'],
#  ['takes', 'massive', 'lead', 'wsj', 'support'],
#  ['trump',
#   'surges',
#   '-',
#   'takes',
#   'double',
#   'digit',
#   'lead',
#   'presidential',
#   'race',
#   '@realdonaldtrump'],
#  ['@danscavino:',
#   'good',
#   'real',
#   'clear',
#   'polling',
#   'data',
#   'average',
#   'w/',
#   'bloomberg',
#   'poll.',
#   '@realdonaldtrump',
#   '#1.',
#   '#trump2016',
#   'http:…'],
#  ['trump',
#   'continues',
#   'rise',
#   'polls!',
#   'american',
#   'people',
#   'speaking',
#   'speaking'],
#  ['"@roniseale:',
#   'trump',
#   'breaking',
#   'every',
#   'poll',
#   '#makeamericagreatagain',
#   '#trump2016'],
#  ['@foxandfriends:',
#   'fox',
#   'news',
#   'poll:',
#   'new',
#   'high',
#   'donald',
#   'trump,',
#   'new',
#   'low',
#   'hillary',
#   'clinton'],
#  ['new',
#   'wsj/nbc',
#   'poll',
#   'finds',
#   'almost',
#   'every',
#   'candidate',
#   'losing',
#   'except',
#   'donald',
#   'trump.'],
#  ['@danscavino:',
#   'fox',
#   'news',
#   'poll',
#   'released',
#   '#1.',
#   '@realdonaldtrump',
#   '•',
#   'jeb',
#   'bush',
#   '•',
#   '15%',
#   'walker',
#   '•',
#   '9%',
#   '#makeamericagreatagain🇺🇸',
#   'http://…'],
#  ['poll:', 'trump', 'bush', 'walker', 'favorability', '52%'],
#  ['new', 'poll', 'shows', 'donald', 'trump', 'everyone', 'else'],
#  ['.@realdonaldtrump',
#   'surges',
#   'nbc',
#   'take',
#   'center',
#   'stage',
#   'makes',
#   'top',
#   'http:…'],
#  ['@foxandfriends:',
#   'first',
#   'republican',
#   'presidential',
#   'debate,',
#   '@realdonaldtrump',
#   'surges',
#   'lead',
#   'among'],
#  ['"@foxnews:',
#   '.@ericbolling:',
#   '"polls',
#   '[@realdonaldtrump',
#   'would]',
#   'today."'],
#  ['leading', 'center', 'stage', 'position'],
#  ['.@ericbolling:', '"polls', '[@realdonaldtrump', 'would]', 'today."']]

# %%
# Create dictionary of document
bag = corpora.Dictionary(texts)
bag.save('trump.dict')

# Converting document to a vector (bag-of-words)
corpus = [bag.doc2bow(text) for text in texts]
corpora.MmCorpus.serialize('trump.mm', corpus)
# Out:
# 2018-06-25 12:24:56,703 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2018-06-25 12:24:56,713 : INFO : built Dictionary(661 unique tokens: ['clinton', 'trump', '-', '@realdonaldtrump"', 'breitbart']...) from 448 documents (total 3791 corpus positions)
# 2018-06-25 12:24:56,715 : INFO : saving Dictionary object under trump.dict, separately None
# 2018-06-25 12:24:56,717 : INFO : saved trump.dict
# 2018-06-25 12:24:56,722 : INFO : storing corpus in Matrix Market format to trump.mm
# 2018-06-25 12:24:56,723 : INFO : saving sparse matrix to trump.mm
# 2018-06-25 12:24:56,723 : INFO : PROGRESS: saving document #0
# 2018-06-25 12:24:56,732 : INFO : saved 448x661 matrix, density=1.253% (3710/296128)
# 2018-06-25 12:24:56,735 : INFO : saving MmCorpus index to trump.mm.index

# %% [markdown]
# We have assigned a unique integer id to all words appearing in the corpus by:
#
#    1. sweeping across the texts
#    2. collecting word counts and relevant statistics
#
# Our corpus is a 448 x 661 matrix.
#
# ***
#
# ### Transformation: _tf-idf_
#
# #### Step 1:

# %%
# Initialization
tfidf = models.TfidfModel(corpus)
# Out:
# 2018-06-25 12:25:42,894 : INFO : collecting document frequencies
# 2018-06-25 12:25:42,895 : INFO : PROGRESS: processing document #0
# 2018-06-25 12:25:42,897 : INFO : calculating IDF weights for 448 documents and 660 features (3710 matrix non-zeros)

# %% [markdown]
# We have initialized (trained) a transaformation model. Different transformation may require different initialization parameters; however, in our case, ___tf-idf___, the "training" consists simply of going through the supplied corpus once and computing document frequencies of all its features. This is in comparison to ___Latent Semantic Analysis___ & ___Latent Dirichlet Allocation___ which are more involved and take more time.
#
# |Note:|
# |---|
# |**A note on transaformations**<br>Transformations always convert between two specific vector spaces. The same vector space (= the same set of feature ids) must be used for training as well as for subsequent vector transformations. Failure to use the same input feature space, such as applying a different string preprocessing, using different feature ids, or using bag-of-words input vectors where ___tf-idf___ vectors are expceted, will result in feature mismatch during transformation calls and consequently in either garbage output and/or runtime exceptions.|
#
# #### Step 2:
# From now on, ___tf-idf___ is treated as a read-only object that can be used to convert any vector from the old representation (___bag-of-words___ integer counts) to the new representation (___tf-idf___ real-valued weights).

# %%
# Applying the transformation to the whole corpus
corpus_tfidf = tfidf[corpus]

# %% [markdown]
# We have transformed our corpus (the one we used for training) into a weighted vector. We can do this for any vector (provided they come from the same vector space), even if they are not used in the corpus at all. This can be achived by _folding-in_ for ___LSA___ and by _topic inference_ for ___LDA___.
#
# #### Step 3:
# We will transform our ___tf-idf___ corpus via [Latent Semantic Indexing](https://en.wikipedia.org/wiki/Latent_semantic_indexing) into a latent 2-D space (... num_topics = 2).

# %%
# Initializing an LSI transformation
lsi = models.LsiModel(corpus_tfidf, id2word=bag, num_topics=10)
corpus_lsi = lsi[corpus_tfidf]
# Out:
# 2018-06-25 12:59:16,657 : INFO : using serial LSI version on this node
# 2018-06-25 12:59:16,659 : INFO : updating model with new documents
# 2018-06-25 12:59:16,684 : INFO : preparing a new chunk of documents
# 2018-06-25 12:59:16,689 : INFO : using 100 extra samples and 2 power iterations
# 2018-06-25 12:59:16,691 : INFO : 1st phase: constructing (661, 102) action matrix
# 2018-06-25 12:59:16,694 : INFO : orthonormalizing (661, 102) action matrix
# 2018-06-25 12:59:16,707 : INFO : 2nd phase: running dense svd on (102, 448) matrix
# 2018-06-25 12:59:16,713 : INFO : computing the final decomposition
# 2018-06-25 12:59:16,715 : INFO : keeping 2 factors (discarding 90.109% of energy spectrum)
# 2018-06-25 12:59:16,717 : INFO : processed documents up to #448
# 2018-06-25 12:59:16,720 : INFO : topic #0(3.923): 0.397*"thank" + 0.390*"you!" + 0.350*"#makeamericagreatagain" + 0.333*"#trump2016" + 0.305*"great" + 0.287*"new" + 0.197*"poll" + 0.158*"-" + 0.141*"poll-" + 0.115*"trump"
# 2018-06-25 12:59:16,721 : INFO : topic #1(2.977): 0.395*"trump" + -0.252*"you!" + 0.225*"carson" + 0.224*"rubio" + -0.222*"#makeamericagreatagain" + -0.221*"thank" + 0.189*"donald" + 0.181*"cruz" + 0.180*"leads" + -0.171*"#trump2016"

# %%
lsi.print_topics()
# Out:
# 2018-06-25 12:59:18,785 : INFO : topic #0(3.923): 0.397*"thank" + 0.390*"you!" + 0.350*"#makeamericagreatagain" + 0.333*"#trump2016" + 0.305*"great" + 0.287*"new" + 0.197*"poll" + 0.158*"-" + 0.141*"poll-" + 0.115*"trump"
# 2018-06-25 12:59:18,787 : INFO : topic #1(2.977): 0.395*"trump" + -0.252*"you!" + 0.225*"carson" + 0.224*"rubio" + -0.222*"#makeamericagreatagain" + -0.221*"thank" + 0.189*"donald" + 0.181*"cruz" + 0.180*"leads" + -0.171*"#trump2016"
# [(0,
#   '0.397*"thank" + 0.390*"you!" + 0.350*"#makeamericagreatagain" + 0.333*"#trump2016" + 0.305*"great" + 0.287*"new" + 0.197*"poll" + 0.158*"-" + 0.141*"poll-" + 0.115*"trump"'),
#  (1,
#   '0.395*"trump" + -0.252*"you!" + 0.225*"carson" + 0.224*"rubio" + -0.222*"#makeamericagreatagain" + -0.221*"thank" + 0.189*"donald" + 0.181*"cruz" + 0.180*"leads" + -0.171*"#trump2016"')]

# %%
# Executing: bow->tfidf and tfidf->lsi
for doc in corpus_lsi:
    print(doc)
# Out:
# [(0, 0.078228657691018624), (1, 0.20441856013733928)]
# [(0, 0.10399650442590408), (1, 0.22113317538330826)]
# [(0, 0.78184555903613062), (1, -0.23477329139145126)]
# [(0, 0.13205131474465895), (1, 0.084383665640546737)]
# [(0, 0.23495335900996084), (1, -0.072539491674543627)]
# [(0, 0.3974676632358502), (1, -0.16024415035280648)]
# [(0, 0.0076834182013354301), (1, 0.01549544062069653)]
# [(0, 0.53752700987304913), (1, -0.27054673114524025)]
# [(0, 0.71406744540841161), (1, -0.21942684627541553)]
# [(0, 0.04885979933659533), (1, 0.10524240050998415)]
# [(0, 0.039155577547600448), (1, 0.082878199330299843)]
# [(0, 0.079871920448168279), (1, 0.11811657422844493)]
# [(0, 0.045562650462120866), (1, 0.075583225103822704)]
# [(0, 0.067615611833345107), (1, 0.23531093446620557)]
# [(0, 0.05602584164514008), (1, 0.15243467145338693)]
# [(0, 0.061713107788134679), (1, 0.19446546097224204)]
# [(0, 0.084436072261469944), (1, 0.22298087053814797)]
# [(0, 0.082776111036771891), (1, 0.1005159068163186)]
# [(0, 0.085804424820950007), (1, 0.30892628372027198)]
# [(0, 0.039686865281213422), (1, 0.089181236460981084)]
# [(0, 0.08556658070354034), (1, 0.17604806965795339)]
# [(0, 0.10660881499050227), (1, 0.03541430890436878)]
# [(0, 0.020431969010207156), (1, 0.068050853271666378)]
# [(0, 0.2652850097140898), (1, -0.0053480247610266938)]
# [(0, 0.12920733612765273), (1, 0.15626517719304053)]
# [(0, 0.079985789680289535), (1, 0.11140206333035445)]
# [(0, 0.056929216380102704), (1, 0.11587975717275906)]
# [(0, 0.0524900655117784), (1, 0.17132133313947273)]
# [(0, 0.12878351279591987), (1, 0.20914511237456376)]
# [(0, 0.017884725221039656), (1, 0.04544491799217544)]
# [(0, 0.053462578640563453), (1, 0.13156868892148321)]
# [(0, 0.0004092197647663395), (1, 0.0020305025250542596)]
# [(0, 0.013533668508038922), (1, 0.030669034914615978)]
# [(0, -7.0139891743888869e-05), (1, -0.00044909684324257295)]

# %%
# Model persistence: save(), load()
lsi.save('trump.lsi')
lsi = models.LsiModel.load('trump.lsi')
# Out:
# 2018-06-25 13:06:28,068 : INFO : saving Projection object under trump.lsi.projection, separately None
# 2018-06-25 13:06:28,070 : INFO : saved trump.lsi.projection
# 2018-06-25 13:06:28,070 : INFO : saving LsiModel object under trump.lsi, separately None
# 2018-06-25 13:06:28,071 : INFO : not storing attribute projection
# 2018-06-25 13:06:28,072 : INFO : not storing attribute dispatcher
# 2018-06-25 13:06:28,073 : INFO : saved trump.lsi
# 2018-06-25 13:06:28,074 : INFO : loading LsiModel object from trump.lsi
# 2018-06-25 13:06:28,078 : INFO : loading id2word recursively from trump.lsi.id2word.* with mmap=None
# 2018-06-25 13:06:28,078 : INFO : setting ignored attribute projection to None
# 2018-06-25 13:06:28,079 : INFO : setting ignored attribute dispatcher to None
# 2018-06-25 13:06:28,079 : INFO : loaded trump.lsi
# 2018-06-25 13:06:28,080 : INFO : loading LsiModel object from trump.lsi.projection
# 2018-06-25 13:06:28,081 : INFO : loaded trump.lsi.projection

# %% [markdown]
# ***
# ### Similarity
#
# #### Step 1:

# %%
# Initializing the query structure: transform corpus to LSI space and index it
index = similarities.MatrixSimilarity(lsi[corpus])
# Out:
# 2018-06-25 13:06:30,809 : WARNING : scanning corpus to determine the number of features (consider setting `num_features` explicitly)
# 2018-06-25 13:06:30,818 : INFO : creating matrix with 448 documents and 2 features

# %%
# Index persistence
index.save('trump.index')
index = similarities.MatrixSimilarity.load('trump.index')
# Out:
