# %% [markdown]
# # Loan Prediction Challenge: Feature Selection
#
# In this notebook we will select features to use from the `feature_matrix.csv` file before training and testing models.
#
# We will use the `feature_selector` script created by [Will Koehrsen](https://github.com/WillKoehrsen).

# %%
# Header
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

# %%
# Imports
import pandas as pd

from feature_selector import FeatureSelector

# %%
# Reading in the data
fmat = pd.read_csv('../data/feature_matrix.csv')

# %%
# Dropping missing value labels
fmat.dropna(subset=['good_bad_flag'], inplace=True)

# Formatting
fmat_labels = fmat['good_bad_flag']
fmat = fmat.drop(columns=['good_bad_flag'])

# %% [markdown]
# ## Create the Instance

# %%
fs = FeatureSelector(data=fmat, labels=fmat_labels)

# %% [markdown]
# ## Implement
#
# We will identify and remove:
# >1. features with a significant amount of missing values
# >2. features that contain a single unique value
# >3. highly correlated features
# >4. zero importance features
# >5. low importance features

# %%
# Parameters
selection_params = {'missing_threshold': .25,
                    'correlation_threshold': .99,
                    'task': 'classification',
                    'eval_metric': 'auc',
                    'cumulative_importance': .99}

# Identify
fs.identify_all(selection_params=selection_params)

# Remove
new_feature_matrix = fs.remove(methods='all', keep_one_hot=False)
# Out:
# 4 features with greater than 0.25 missing values.
#
# 7 features with a single unique value.
#
# 44 features with a correlation magnitude greater than 0.99.
#
# Training Gradient Boosting Model
#
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [25]	valid_0's auc: 0.675029	valid_0's binary_logloss: 0.472358
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [32]	valid_0's auc: 0.664959	valid_0's binary_logloss: 0.489681
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [17]	valid_0's auc: 0.598523	valid_0's binary_logloss: 0.519537
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [3]	valid_0's auc: 0.59927	valid_0's binary_logloss: 0.529272
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [34]	valid_0's auc: 0.653387	valid_0's binary_logloss: 0.47898
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [23]	valid_0's auc: 0.602547	valid_0's binary_logloss: 0.503551
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1]	valid_0's auc: 0.663009	valid_0's binary_logloss: 0.539565
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [51]	valid_0's auc: 0.661885	valid_0's binary_logloss: 0.484299
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [16]	valid_0's auc: 0.604553	valid_0's binary_logloss: 0.516382
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [23]	valid_0's auc: 0.61686	valid_0's binary_logloss: 0.516611
#
# 14244 features with zero importance after one-hot encoding.
#
# 63 features required for cumulative importance of 0.99 after one hot encoding.
# 14263 features do not contribute to cumulative importance of 0.99.
#
# 14278 total features out of 14336 identified for removal after one-hot encoding.
#
# ['missing', 'single_unique', 'collinear', 'zero_importance', 'low_importance'] methods have been run
#
# Removed 14290 features including one-hot features.

# %%
fs.plot_feature_importances(threshold=.99, plot_n=10)
# Out:
# 64 features required for 0.99 of cumulative importance

# %%
# Concatenate
df = pd.concat([new_feature_matrix, fmat_labels], axis=1, sort=False)

# Missing values
df.dropna(inplace=True)

assert df.isnull().sum().values.sum() == 0

# %%
# Save
df.to_csv('../data/new_feature_matrix.csv', index=False)

# %% [markdown]
# ## References
#
# - Will Koehrsen's GitHub repo can be found [here](https://github.com/WillKoehrsen)
