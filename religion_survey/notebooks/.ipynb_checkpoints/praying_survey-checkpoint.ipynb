# %% [markdown]
# # When does praying in public make others uncomfortable?
#
# This is the data behind the story [When Does Praying In Public Make Others Uncomfortable?](https://fivethirtyeight.com/features/when-does-praying-in-public-make-others-uncomfortable/).
# <br><br/>
# Data was collected using a [SurveyMonkey](https://surveymonkey.com) poll, conducted between July 29 and August 1, 2016. 661 gave responses to questions about public displays of religion.

# %%
# The usual suspects
import itertools
import numpy as np
import pandas as pd
import missingno as msn
import cleaner2 as clr
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns

# %%
# Getting the data
df = pd.read_csv('religion-survey-results.csv')

# %%
df.shape
# Out:
# (1040, 48)

# %%
df.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1040 entries, 0 to 1039
# Columns: 48 entries, What is your present religion, if any? to US Region
# dtypes: object(48)
# memory usage: 390.1+ KB

# %% [markdown]
# ### Step 1: Preprocessing
#
# #### 1.1. Columns
#
# Some columns are badly labelled and need to have more descriptive labels.

# %%
df.rename(columns={'Unnamed: 1': 'Which church do you attend?'}, inplace=True)

# %% [markdown]
# #### 1.2. Redundant data entries
#
# The first column of our data has a single entry for the whole row.

# %%
df.drop(df.index[[0]], inplace=True)
df.shape
# Out:
# (1039, 48)

# %% [markdown]
# #### 1.3. Text case
#
# Most of our data is textual. We want to have a uniform letter-case for all the entries. This will reduce errors in bad entries.

# %%
clr.word_case(dataframe=df)
# Out:
# Done.
#   What is your present religion, if any?  \
# 1                          None Of These
# 2                                Atheist
# 3                             Protestant
# 4                                 Muslim
# 5                          None Of These
#
#                          Which church do you attend?  \
# 1                                 Wesleyan Christian
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  Working On Christianity. Orthodox Seemed Too C...
#
#   Do you consider yourself to be an evangelical?  \
# 1                                             No
# 2                                            NaN
# 3                                             No
# 4                                             No
# 5                                             No
#
#   Do you attend religious services  \
# 1                   Weekly Or More
# 2                              NaN
# 3                   Weekly Or More
# 4                   Weekly Or More
# 5                   Weekly Or More
#
#   How often do you: Pray in public with visible motions (sign of the cross, bowing, prostration, shokeling, etc)  \
# 1                               A Few Times Per Week
# 2                                                NaN
# 3                              A Few Times Per Month
# 4                                          Every Day
# 5                                              Never
#
#   How often do you: Pray in public using some kind of physical object (rosary, tefillin, etc)  \
# 1             Not Applicable To My Religious Beliefs
# 2                                                NaN
# 3                                              Never
# 4                              A Few Times Per Month
# 5                                              Never
#
#   How often do you: Pray aloud before meals in the presence of people who don't belong to your religion  \
# 1                              A Few Times Per Month
# 2                                                NaN
# 3                                Once A Year Or Less
# 4                                              Never
# 5                                              Never
#
#   How often do you: Tell someone you'll pray for him or her  \
# 1                               A Few Times Per Week
# 2                                                NaN
# 3                              A Few Times Per Month
# 4                               Once A Month Or Less
# 5                               Once A Month Or Less
#
#   How often do you: Ask or offer to pray with someone  \
# 1                                              Never
# 2                                                NaN
# 3                              A Few Times Per Month
# 4                               Once A Month Or Less
# 5                              A Few Times Per Month
#
#   How often do you: Bring up your religion, unprompted, in conversation  \
# 1                              A Few Times Per Month
# 2                                                NaN
# 3                              A Few Times Per Month
# 4                                              Never
# 5                               Once A Month Or Less
#
#           ...          \
# 1         ...
# 2         ...
# 3         ...
# 4         ...
# 5         ...
#
#   How comfortable would you be seeing someone who practices a different religion from you: Ask or offer to pray with you  \
# 1                              Extremely Comfortable
# 2                                   Very Comfortable
# 3                              Extremely Comfortable
# 4                                   Very Comfortable
# 5                                 Not So Comfortable
#
#   How comfortable would you be seeing someone who practices a different religion from you: Bring up his or her own religion, unprompted, in conversation  \
# 1                              Extremely Comfortable
# 2                               Somewhat Comfortably
# 3                              Extremely Comfortable
# 4                                   Very Comfortable
# 5                                 Not So Comfortable
#
#   How comfortable would you be seeing someone who practices a different religion from you: Ask you about your religion, unprompted, in conversation  \
# 1                              Extremely Comfortable
# 2                                   Very Comfortable
# 3                              Extremely Comfortable
# 4                                   Very Comfortable
# 5                                 Not So Comfortable
#
#   How comfortable would you be seeing someone who practices a different religion from you: Decline some kind of food or beverage for religious reasons (kosher, halal, fasting rules, etc)  \
# 1                              Extremely Comfortable
# 2                              Extremely Comfortable
# 3                              Extremely Comfortable
# 4                                   Very Comfortable
# 5                                 Not So Comfortable
#
#   How comfortable would you be seeing someone who practices a different religion from you: Wear religious clothing/jewelry (hijab, kippah, wig, kara, turban, cross, etc)  \
# 1                              Extremely Comfortable
# 2                              Extremely Comfortable
# 3                              Extremely Comfortable
# 4                                   Very Comfortable
# 5                                   Very Comfortable
#
#   How comfortable would you be seeing someone who practices a different religion from you: Participate in a public religious event on the streets (Corpus Christi procession, inauguration of Torah scrolls, etc)  \
# 1                              Extremely Comfortable
# 2                              Extremely Comfortable
# 3                              Extremely Comfortable
# 4                                   Very Comfortable
# 5                               Somewhat Comfortably
#
#   What is your age? What is your gender?  \
# 1           18 - 29                 Male
# 2           18 - 29                 Male
# 3           18 - 29                 Male
# 4           18 - 29                 Male
# 5           18 - 29                 Male
#
#   How much total combined money did all members of your HOUSEHOLD earn last year?  \
# 1                                       $0 To $9,999
# 2                                 $10,000 To $24,999
# 3                                 $25,000 To $49,999
# 4                                       $0 To $9,999
# 5                                 $75,000 To $99,999
#
#             US Region
# 1  East North Central
# 2     Middle Atlantic
# 3  East North Central
# 4      South Atlantic
# 5             Pacific
#
# [5 rows x 48 columns]

# %% [markdown]
# We also need to fix the columns. We'll put them in sentence-case.

# %%
# Capitalizing the columns
df.columns = df.columns.str.capitalize()

# Fixing columns
df.rename(columns={'Us region' : 'US region'}, inplace=True)

# %% [markdown]
# #### 1.4. Missing values
#
# We have great deal of missing values that compromise the quality of our data. We need to impute dummy values inplace of `np.Nan` values.

# %%
df.isnull().sum().plot.barh(figsize=(9, 20))
plt.grid()

# %% [markdown]
# The column _"Which church do you attend?"_ has the highest number of missing values. Close to 800 values are missing. We will use ***cleaner's*** `remove_columns` function to lower the number of variables with too many missing values.

# %%
clr.remove_columns(df)
# Out:
# Initial shape of the dataset:(1039, 48)
#
# The following will be removed: Which church do you attend?
#
# Final shape of the dataset:(1039, 47)
#   What is your present religion, if any?  \
# 1                          None Of These
# 2                                Atheist
# 3                             Protestant
# 4                                 Muslim
# 5                          None Of These
#
#   Do you consider yourself to be an evangelical?  \
# 1                                             No
# 2                                            NaN
# 3                                             No
# 4                                             No
# 5                                             No
#
#   Do you attend religious services  \
# 1                   Weekly Or More
# 2                              NaN
# 3                   Weekly Or More
# 4                   Weekly Or More
# 5                   Weekly Or More
#
#   How often do you: pray in public with visible motions (sign of the cross, bowing, prostration, shokeling, etc)  \
# 1                               A Few Times Per Week
# 2                                                NaN
# 3                              A Few Times Per Month
# 4                                          Every Day
# 5                                              Never
#
#   How often do you: pray in public using some kind of physical object (rosary, tefillin, etc)  \
# 1             Not Applicable To My Religious Beliefs
# 2                                                NaN
# 3                                              Never
# 4                              A Few Times Per Month
# 5                                              Never
#
#   How often do you: pray aloud before meals in the presence of people who don't belong to your religion  \
# 1                              A Few Times Per Month
# 2                                                NaN
# 3                                Once A Year Or Less
# 4                                              Never
# 5                                              Never
#
#   How often do you: tell someone you'll pray for him or her  \
# 1                               A Few Times Per Week
# 2                                                NaN
# 3                              A Few Times Per Month
# 4                               Once A Month Or Less
# 5                               Once A Month Or Less
#
#   How often do you: ask or offer to pray with someone  \
# 1                                              Never
# 2                                                NaN
# 3                              A Few Times Per Month
# 4                               Once A Month Or Less
# 5                              A Few Times Per Month
#
#   How often do you: bring up your religion, unprompted, in conversation  \
# 1                              A Few Times Per Month
# 2                                                NaN
# 3                              A Few Times Per Month
# 4                                              Never
# 5                               Once A Month Or Less
#
#   How often do you: ask others about their religion, unprompted, in conversation  \
# 1                              A Few Times Per Month
# 2                                                NaN
# 3                               Once A Month Or Less
# 4                                Once A Year Or Less
# 5                                Once A Year Or Less
#
#           ...          \
# 1         ...
# 2         ...
# 3         ...
# 4         ...
# 5         ...
#
#   How comfortable would you be seeing someone who practices a different religion from you: ask or offer to pray with you  \
# 1                              Extremely Comfortable
# 2                                   Very Comfortable
# 3                              Extremely Comfortable
# 4                                   Very Comfortable
# 5                                 Not So Comfortable
#
#   How comfortable would you be seeing someone who practices a different religion from you: bring up his or her own religion, unprompted, in conversation  \
# 1                              Extremely Comfortable
# 2                               Somewhat Comfortably
# 3                              Extremely Comfortable
# 4                                   Very Comfortable
# 5                                 Not So Comfortable
#
#   How comfortable would you be seeing someone who practices a different religion from you: ask you about your religion, unprompted, in conversation  \
# 1                              Extremely Comfortable
# 2                                   Very Comfortable
# 3                              Extremely Comfortable
# 4                                   Very Comfortable
# 5                                 Not So Comfortable
#
#   How comfortable would you be seeing someone who practices a different religion from you: decline some kind of food or beverage for religious reasons (kosher, halal, fasting rules, etc)  \
# 1                              Extremely Comfortable
# 2                              Extremely Comfortable
# 3                              Extremely Comfortable
# 4                                   Very Comfortable
# 5                                 Not So Comfortable
#
#   How comfortable would you be seeing someone who practices a different religion from you: wear religious clothing/jewelry (hijab, kippah, wig, kara, turban, cross, etc)  \
# 1                              Extremely Comfortable
# 2                              Extremely Comfortable
# 3                              Extremely Comfortable
# 4                                   Very Comfortable
# 5                                   Very Comfortable
#
#   How comfortable would you be seeing someone who practices a different religion from you: participate in a public religious event on the streets (corpus christi procession, inauguration of torah scrolls, etc)  \
# 1                              Extremely Comfortable
# 2                              Extremely Comfortable
# 3                              Extremely Comfortable
# 4                                   Very Comfortable
# 5                               Somewhat Comfortably
#
#   What is your age? What is your gender?  \
# 1           18 - 29                 Male
# 2           18 - 29                 Male
# 3           18 - 29                 Male
# 4           18 - 29                 Male
# 5           18 - 29                 Male
#
#   How much total combined money did all members of your household earn last year?  \
# 1                                       $0 To $9,999
# 2                                 $10,000 To $24,999
# 3                                 $25,000 To $49,999
# 4                                       $0 To $9,999
# 5                                 $75,000 To $99,999
#
#             US region
# 1  East North Central
# 2     Middle Atlantic
# 3  East North Central
# 4      South Atlantic
# 5             Pacific
#
# [5 rows x 47 columns]

# %% [markdown]
# As expected, the column _"Which church do you attend?"_ was the only one that was removed.

# %%
print(df.shape)
df.dropna(inplace=True)
print(df.shape)
# Out:
# (1039, 47)
# (756, 47)

# %%
assert (df.isnull().sum().all() == 0)

# %% [markdown]
# We now have a clean dataset with no missing values.

# %% [markdown]
# #### 1.5. Bad entries

# %%
clr.unique_value_counts(df)
# Out:
# ===========================================================================
#  Column Name:  What is your present religion, if any?
#
#  ['None Of These' 'Protestant' 'Muslim' 'Agnostic' 'Roman Catholic' 'Hindu'
#  'Jewish' 'Orthodox Christian' 'Mormon' 'Buddhist']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  Do you consider yourself to be an evangelical?
#
#  ['No' 'Yes']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  Do you attend religious services
#
#  ['Weekly Or More' 'Less Than Weekly' 'Never']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How often do you: pray in public with visible motions (sign of the cross, bowing, prostration, shokeling, etc)
#
#  ['A Few Times Per Week' 'A Few Times Per Month' 'Every Day' 'Never'
#  'Once A Year Or Less' 'Once A Month Or Less'
#  'Not Applicable To My Religious Beliefs']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How often do you: pray in public using some kind of physical object (rosary, tefillin, etc)
#
#  ['Not Applicable To My Religious Beliefs' 'Never' 'A Few Times Per Month'
#  'Once A Year Or Less' 'A Few Times Per Week' 'Every Day'
#  'Once A Month Or Less']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How often do you: pray aloud before meals in the presence of people who don't belong to your religion
#
#  ['A Few Times Per Month' 'Once A Year Or Less' 'Never'
#  'Once A Month Or Less' 'Not Applicable To My Religious Beliefs'
#  'A Few Times Per Week' 'Every Day']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How often do you: tell someone you'll pray for him or her
#
#  ['A Few Times Per Week' 'A Few Times Per Month' 'Once A Month Or Less'
#  'Never' 'Once A Year Or Less' 'Every Day'
#  'Not Applicable To My Religious Beliefs']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How often do you: ask or offer to pray with someone
#
#  ['Never' 'A Few Times Per Month' 'Once A Month Or Less'
#  'Once A Year Or Less' 'A Few Times Per Week' 'Every Day'
#  'Not Applicable To My Religious Beliefs']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How often do you: bring up your religion, unprompted, in conversation
#
#  ['A Few Times Per Month' 'Never' 'Once A Month Or Less' 'Every Day'
#  'A Few Times Per Week' 'Once A Year Or Less'
#  'Not Applicable To My Religious Beliefs']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How often do you: ask others about their religion, unprompted, in conversation
#
#  ['A Few Times Per Month' 'Once A Month Or Less' 'Once A Year Or Less'
#  'Never' 'Not Applicable To My Religious Beliefs' 'A Few Times Per Week'
#  'Every Day']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How often do you: decline some kind of food or beverage for religious reasons (kosher, halal, fasting rules, etc)
#
#  ['Once A Year Or Less' 'Never' 'Every Day'
#  'Not Applicable To My Religious Beliefs' 'A Few Times Per Month'
#  'Once A Month Or Less' 'A Few Times Per Week']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How often do you: wear religious clothing/jewelry (hijab, kippah, wig, kara, turban, cross, etc)
#
#  ['A Few Times Per Week' 'Once A Month Or Less' 'Every Day' 'Never'
#  'Not Applicable To My Religious Beliefs' 'A Few Times Per Month'
#  'Once A Year Or Less']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How often do you: participate in a public religious event on the streets (corpus christi procession, inauguration of torah scrolls, etc)
#
#  ['Once A Year Or Less' 'Never' 'Once A Month Or Less'
#  'Not Applicable To My Religious Beliefs' 'A Few Times Per Week'
#  'A Few Times Per Month' 'Every Day']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How comfortable do you feel when you: pray in public with visible motions (sign of the cross, bowing, prostration, shokeling, etc)
#
#  ['Not So Comfortable' 'Extremely Comfortable' "I Don'T Do This"
#  'Somewhat Comfortably' 'Not At All Comfortable' 'Very Comfortable']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How comfortable do you feel when you: pray in public using some kind of physical object (rosary, tefillin, etc)
#
#  ["I Don'T Do This" 'Somewhat Comfortably' 'Not So Comfortable'
#  'Not At All Comfortable' 'Extremely Comfortable' 'Very Comfortable']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How comfortable do you feel when you: pray aloud before meals in the presence of people who don't belong to your religion
#
#  ['Not At All Comfortable' 'Extremely Comfortable' "I Don'T Do This"
#  'Somewhat Comfortably' 'Very Comfortable' 'Not So Comfortable']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How comfortable do you feel when you: tell someone you'll pray for him or her
#
#  ['Extremely Comfortable' 'Somewhat Comfortably' "I Don'T Do This"
#  'Very Comfortable' 'Not At All Comfortable' 'Not So Comfortable']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How comfortable do you feel when you: ask or offer to pray with someone
#
#  ["I Don'T Do This" 'Extremely Comfortable' 'Somewhat Comfortably'
#  'Very Comfortable' 'Not So Comfortable' 'Not At All Comfortable']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How comfortable do you feel when you: bring up your religion, unprompted, in conversation
#
#  ['Very Comfortable' 'Extremely Comfortable' 'Not So Comfortable'
#  "I Don'T Do This" 'Somewhat Comfortably' 'Not At All Comfortable']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How comfortable do you feel when you: ask others about their religion, unprompted, in conversation
#
#  ['Very Comfortable' 'Somewhat Comfortably' 'Extremely Comfortable'
#  'Not So Comfortable' "I Don'T Do This" 'Not At All Comfortable']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How comfortable do you feel when you: decline some kind of food or beverage for religious reasons (kosher, halal, fasting rules, etc)
#
#  ['Very Comfortable' "I Don'T Do This" 'Extremely Comfortable'
#  'Not At All Comfortable' 'Somewhat Comfortably' 'Not So Comfortable']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How comfortable do you feel when you: wear religious clothing/jewelry (hijab, kippah, wig, kara, turban, cross, etc)
#
#  ['Extremely Comfortable' 'Very Comfortable' "I Don'T Do This"
#  'Somewhat Comfortably' 'Not At All Comfortable' 'Not So Comfortable']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How comfortable do you feel when you: participate in a public religious event on the streets (corpus christi procession, inauguration of torah scrolls, etc)
#
#  ['Very Comfortable' 'Extremely Comfortable' "I Don'T Do This"
#  'Somewhat Comfortably' 'Not So Comfortable' 'Not At All Comfortable']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How comfortable do you think someone outside your religion would be if they saw you: pray in public with visible motions (sign of the cross, bowing, prostration, shokeling, etc)
#
#  ["I Don'T Do This" 'Somewhat Comfortably' 'Extremely Comfortable'
#  'Very Comfortable' 'Not So Comfortable' 'Not At All Comfortable']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How comfortable do you think someone outside your religion would be if they saw you: pray in public using some kind of physical object (rosary, tefillin, etc)
#
#  ["I Don'T Do This" 'Somewhat Comfortably' 'Not So Comfortable'
#  'Extremely Comfortable' 'Not At All Comfortable' 'Very Comfortable']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How comfortable do you think someone outside your religion would be if they saw you: pray aloud before meals in the presence of people who don't belong to your religion
#
#  ['Somewhat Comfortably' "I Don'T Do This" 'Not So Comfortable'
#  'Extremely Comfortable' 'Very Comfortable' 'Not At All Comfortable']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How comfortable do you think someone outside your religion would be if they saw you: tell someone you'll pray for him or her
#
#  ['Somewhat Comfortably' 'Not So Comfortable' "I Don'T Do This"
#  'Very Comfortable' 'Extremely Comfortable' 'Not At All Comfortable']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How comfortable do you think someone outside your religion would be if they saw you: ask or offer to pray with someone
#
#  ['Somewhat Comfortably' 'Very Comfortable' 'Not So Comfortable'
#  "I Don'T Do This" 'Not At All Comfortable' 'Extremely Comfortable']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How comfortable do you think someone outside your religion would be if they saw you: bring up your religion, unprompted, in conversation
#
#  ['Somewhat Comfortably' 'Extremely Comfortable' 'Not So Comfortable'
#  "I Don'T Do This" 'Not At All Comfortable' 'Very Comfortable']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How comfortable do you think someone outside your religion would be if they saw you: ask others about their religion, unprompted, in conversation
#
#  ['Somewhat Comfortably' 'Not So Comfortable' 'Extremely Comfortable'
#  "I Don'T Do This" 'Not At All Comfortable' 'Very Comfortable']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How comfortable do you think someone outside your religion would be if they saw you: decline some kind of food or beverage for religious reasons (kosher, halal, fasting rules, etc)
#
#  ['Somewhat Comfortably' 'Very Comfortable' 'Extremely Comfortable'
#  "I Don'T Do This" 'Not So Comfortable' 'Not At All Comfortable']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How comfortable do you think someone outside your religion would be if they saw you: wear religious clothing/jewelry (hijab, kippah, wig, kara, turban, cross, etc)
#
#  ['Somewhat Comfortably' 'Very Comfortable' 'Extremely Comfortable'
#  "I Don'T Do This" 'Not So Comfortable' 'Not At All Comfortable']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How comfortable do you think someone outside your religion would be if they saw you: participate in a public religious event on the streets (corpus christi procession, inauguration of torah scrolls, etc)
#
#  ["I Don'T Do This" 'Somewhat Comfortably' 'Extremely Comfortable'
#  'Very Comfortable' 'Not At All Comfortable' 'Not So Comfortable']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How comfortable would you be seeing someone who practices a different religion from you: pray in public with visible motions (sign of the cross, bowing, prostration, shokeling, etc)
#
#  ['Extremely Comfortable' 'Very Comfortable' 'Somewhat Comfortably'
#  'Not So Comfortable' 'Not At All Comfortable']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How comfortable would you be seeing someone who practices a different religion from you: pray in public using some kind of physical object (rosary, tefillin, etc)
#
#  ['Extremely Comfortable' 'Very Comfortable' 'Somewhat Comfortably'
#  'Not So Comfortable' 'Not At All Comfortable']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How comfortable would you be seeing someone who practices a different religion from you: pray aloud before meals in the presence of people who don't belong to that religion
#
#  ['Extremely Comfortable' 'Very Comfortable' 'Somewhat Comfortably'
#  'Not So Comfortable' 'Not At All Comfortable']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How comfortable would you be seeing someone who practices a different religion from you: tell someone "i'll pray for you"
#
#  ['Very Comfortable' 'Extremely Comfortable' 'Somewhat Comfortably'
#  'Not At All Comfortable' 'Not So Comfortable']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How comfortable would you be seeing someone who practices a different religion from you: ask or offer to pray with you
#
#  ['Extremely Comfortable' 'Very Comfortable' 'Not So Comfortable'
#  'Somewhat Comfortably' 'Not At All Comfortable']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How comfortable would you be seeing someone who practices a different religion from you: bring up his or her own religion, unprompted, in conversation
#
#  ['Extremely Comfortable' 'Very Comfortable' 'Not So Comfortable'
#  'Somewhat Comfortably' 'Not At All Comfortable']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How comfortable would you be seeing someone who practices a different religion from you: ask you about your religion, unprompted, in conversation
#
#  ['Extremely Comfortable' 'Very Comfortable' 'Not So Comfortable'
#  'Somewhat Comfortably' 'Not At All Comfortable']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How comfortable would you be seeing someone who practices a different religion from you: decline some kind of food or beverage for religious reasons (kosher, halal, fasting rules, etc)
#
#  ['Extremely Comfortable' 'Very Comfortable' 'Not So Comfortable'
#  'Somewhat Comfortably' 'Not At All Comfortable']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How comfortable would you be seeing someone who practices a different religion from you: wear religious clothing/jewelry (hijab, kippah, wig, kara, turban, cross, etc)
#
#  ['Extremely Comfortable' 'Very Comfortable' 'Somewhat Comfortably'
#  'Not At All Comfortable' 'Not So Comfortable']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How comfortable would you be seeing someone who practices a different religion from you: participate in a public religious event on the streets (corpus christi procession, inauguration of torah scrolls, etc)
#
#  ['Extremely Comfortable' 'Very Comfortable' 'Somewhat Comfortably'
#  'Not At All Comfortable' 'Not So Comfortable']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  What is your age?
#
#  ['18 - 29' '45 - 59' '60+' '30 - 44']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  What is your gender?
#
#  ['Male' 'Female']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  How much total combined money did all members of your household earn last year?
#
#  ['$0 To $9,999' '$25,000 To $49,999' '$75,000 To $99,999'
#  '$10,000 To $24,999' '$50,000 To $74,999' 'Prefer Not To Answer'
#  '$125,000 To $149,999' '$100,000 To $124,999' '$200,000 And Up'
#  '$150,000 To $174,999' '$175,000 To $199,999']
#  ===========================================================================
#
# ===========================================================================
#  Column Name:  US region
#
#  ['East North Central' 'South Atlantic' 'Pacific' 'Mountain'
#  'Middle Atlantic' 'West South Central' 'West North Central'
#  'East South Central' 'New England']
#  ===========================================================================
#
# Done.

# %% [markdown]
# The column _"How much total combined money did all members of your household earn last year?"_ has `$` signs and may be interpreted wrongly in our analysis.

# %%
# Replacing '$' signs
series, new_series = df['How much total combined money did all members of your household earn last year?'], list()
obj = (i for i in series.values)
try:
    while True:
        old = obj.__next__()
        new = old.replace('$', '')
        new_series.append(new)
except:
    pass

df['How much total combined money did all members of your household earn last year?'] = new_series
df['How much total combined money did all members of your household earn last year?'] = df['How much total combined money did all members of your household earn last year?'].str.capitalize()
df['How much total combined money did all members of your household earn last year?'].value_counts()
# Out:
# 25,000 to 49,999        136
# 50,000 to 74,999        122
# Prefer not to answer     97
# 75,000 to 99,999         81
# 10,000 to 24,999         77
# 0 to 9,999               71
# 100,000 to 124,999       59
# 125,000 to 149,999       43
# 200,000 and up           32
# 150,000 to 174,999       29
# 175,000 to 199,999        9
# Name: How much total combined money did all members of your household earn last year?, dtype: int64

# %% [markdown]
# ### Step 2: Exploration
#
# #### 2.1. What is your present religion, if any?

# %%
clr.frequency_plot(dataframe=df, 
             x='What is your present religion, if any?', 
             title='What is your present religion?', 
             xlabel='Affiliations')

# %% [markdown]
# Representation of religious affiliation has the greatest number of respondents being unidentified (represented by _"None Of These"_). This is followed by Protestants, Roman Catholics and Agnostics.

# %% [markdown]
# #### 2.1.1. Present religion by gender

# %%
sns.countplot(data=df, x='What is your present religion, if any?', hue='What is your gender?')

# %% [markdown]
# #### 2.1.2. Present religion by age

# %%
sns.countplot(data=df, x='What is your present religion, if any?', 
              hue_order=sorted(df['What is your age?'].unique()), 
              hue='What is your age?')

# %% [markdown]
# Religious identity across age groups shows a higher number of agnostics are aged 18 - 29, with middle-age range of 45 - 59 being the least common. Orthodox Christians and Muslims have a pattern that is almost similar to that of agnostics with a higher number of young people than older people. This is in contrast to Protestants and Roman Catholics that have lower frequencies in the lower age range (18 - 29) and higher frequencies in the upper age groups. Unidentified affiliations have high frequencies for the middle-age groups compared to the lower and upper age groups.

# %% [markdown]
# #### 2.1.3. Present religion and combined household income

# %%
sns.countplot(data=df, 
              x='What is your present religion, if any?', 
              hue_order=sorted(df['How much total combined money did all members of your household earn last year?'].unique()),
              hue='How much total combined money did all members of your household earn last year?')

# %% [markdown]
# #### 2.1.4. Present religion and evangelism

# %%
sns.countplot(data=df, x='What is your present religion, if any?', 
              hue='Do you consider yourself to be an evangelical?')

# %% [markdown]
# #### 2.1.5. Present religion and church attendance

# %%
sns.countplot(data=df, x='What is your present religion, if any?',
              hue='Do you attend religious services')

# %% [markdown]
# #### 2.1.6. Protestants

# %%
protestants = df.loc[(df['What is your present religion, if any?'] == 'Protestant')]

# %% [markdown]
# ##### 2.1.6.1. Protestants and public prayer

# %%
sns.countplot(data=protestants, 
              y='How often do you: pray in public with visible motions (sign of the cross, bowing, prostration, shokeling, etc)')
plt.ylabel('')
# Out:
# Text(0,0.5,'')

# %%
sns.countplot(data=protestants, 
              y='How often do you: pray in public using some kind of physical object (rosary, tefillin, etc)')
plt.ylabel('')
# Out:
# Text(0,0.5,'')

# %%
a = protestants.groupby(
    ['How often do you: pray in public using some kind of physical object (rosary, tefillin, etc)', 
     'What is your age?'])['What is your age?'].count().unstack('What is your age?')
sns.heatmap(a)
plt.title('Praying in public with some physical object', fontsize=16)
plt.ylabel('')
# Out:
# Text(123,0.5,'')

# %%
a = protestants.groupby(
    ['How often do you: pray in public with visible motions (sign of the cross, bowing, prostration, shokeling, etc)', 
     'What is your age?'])['What is your age?'].count().unstack('What is your age?')
sns.heatmap(a)
plt.title('Praying in public with visible motions', fontsize=16)
plt.ylabel('')
# Out:
# Text(123,0.5,'')

# %% [markdown]
# Protestants almost never pray in public with visible motions, whether in the form of a sign of a cross, bowing, prostration, shokeling etc. Respondents over the age of 60 contributed the highest number of _"Never"_ responses related to public displays of prayer.
# <br><br/>
# On the other hand, low numbers of respondents (less than 5) were more common in the lowest age group (18 - 29 years old), while middle age (30 - 59 years old) having the largest contributions to praying in public.
